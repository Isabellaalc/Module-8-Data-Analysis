# %% [markdown]
# # Required Codio activity: Web scraping in action
# ---
#
# ## Overview
#
# In this activity, you will **write Python code to scrape data from a website** using standard libraries and techniques.
#
# This hands-on assignment is designed to:
# - Strengthen your Python coding skills.
# - Reinforce your understanding of key concepts covered in this module.
# - Introduce you to the practical challenges of extracting structured data from unstructured web pages.
#
# As you progress through the tasks, they will gradually increase in complexity. Approach this like a programmer: break problems into smaller parts, test frequently, and debug as needed.
#
# > **Tip:** Run your code after completing each task to check for errors and ensure everything works before moving on.
#
# ---
#
# ### Learning Outcome
#
# - Successfully **scrape a website to extract data** using Python.
#
#
#
# **Please Note:** Since the data is being scraped from the internet, some information may change over time, which is beyond our control. This is expected and perfectly fine, and your submissions will be evaluated with that in mind.

# %% [markdown]
# ## Index:
#
# - [Question 1](#Question-1)
# - [Question 2](#Question-2)
# - [Question 3](#Question-3)
# - [Question 4](#Question-4)
# - [Question 5](#Question-5)

# %% [markdown]
# ###### [Back to top](#Index:)
#
# ### Question 1: Access the Web Page
#
# In this task, you will begin scraping recipe data from the website **[epicurious.com](https://www.epicurious.com)**.
#
# #### Instructions
#
# 1. Open a web browser and visit **https://www.epicurious.com**.
# 2. Inspect the page to get a sense of its structure — use developer tools to explore the HTML elements.
# 3. In your code:
#    - Use the `requests` library to send a **GET** request to the website.
#    - Store the **HTML content** (i.e., the `.text` of the response) in a variable named `ans1`.
#
# > 🧪 **Autograder Check**
# > The autograder will check if the variable `ans1` contains the raw HTML content returned from `https://www.epicurious.com`.
#
# ---
#
# **Expected Output Example** (first 100 characters of `ans1`):
# ```html
# <!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><meta name="viewport" content="width...
# ```

# %%
import requests

ans1 = None
url = "https://www.epicurious.com/"
ans1 = requests.get(url,timeout=1).text

# Answer test
print(ans1[:1000000])
# Out:
# <!DOCTYPE html><html lang="en-US" dir="ltr"><head><title>Epicurious – Recipes, Menu Ideas, Videos &amp; Cooking Tips | Epicurious</title><meta charSet="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta name="msapplication-tap-highlight" content="no"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="author" content="Condé Nast"/><meta name="copyright" content="Copyright (c) Condé Nast 2025"/><meta name="description" content="Since 1995, Epicurious has been the ultimate food resource for the home cook, with daily kitchen tips, fun cooking videos, and, oh yeah, over 33,000 recipes."/><meta name="id" content="6572b7bfdb20f77e6352a50e"/><meta name="keywords" content=""/><meta name="news_keywords" content=""/><meta name="robots" content="index, follow, max-image-preview:large"/><meta name="google-site-verification" content="fbW4-SR7g-pDem3jW4eRKl9571SIF3cQiufsQDaxPds"/><meta name="content-type" content="homepage"/><meta name="parsely-post-id" content="6572b7bfdb20f77e6352a50e"/><meta name="parsely-metadata" content="{&quot;description&quot;:&quot;Since 1995, Epicurious has been the ultimate food resource for the home cook, with daily kitchen tips, fun cooking videos, and, oh yeah, over 33,000 recipes.&quot;,&quot;image-16-9&quot;:&quot;https://assets.epicurious.com/photos/656f72061ce0aa7243171bbd/16:9/w_1000,c_limit/Champagne-Cocktail_RECIPE_V1.jpg&quot;,&quot;image-1-1&quot;:&quot;https://assets.epicurious.com/photos/656f72061ce0aa7243171bbd/1:1/w_1000,c_limit/Champagne-Cocktail_RECIPE_V1.jpg&quot;}"/><meta property="og:description" content="Since 1995, Epicurious has been the ultimate food resource for the home cook, with daily kitchen tips, fun cooking videos, and, oh yeah, over 33,000 recipes."/><meta property="og:image" content="https://assets.epicurious.com/photos/656f72061ce0aa7243171bbd/16:9/w_1280,c_limit/Champagne-Cocktail_RECIPE_V1.jpg"/><meta property="og:site_name" content="Epicurious"/><meta property="og:title" content="Epicurious – Recipes, Menu Ideas, Videos &amp; Cooking Tips"/><meta property="og:type" content="website"/><meta property="og:url" content="https://www.epicurious.com/"/><meta property="article:content_tier" content="free"/><meta http-equiv="content-language" content="en-US"/><meta property="article:author" content="Condé Nast"/><meta property="twitter:card" content="summary_large_image"/><meta property="twitter:creator" content="@epicurious"/><meta property="twitter:description" content="Since 1995, Epicurious has been the ultimate food resource for the home cook, with daily kitchen tips, fun cooking videos, and, oh yeah, over 33,000 recipes."/><meta property="twitter:domain" content="https://www.epicurious.com"/><meta property="twitter:image" content="https://assets.epicurious.com/photos/656f72061ce0aa7243171bbd/16:9/w_1280,c_limit/Champagne-Cocktail_RECIPE_V1.jpg?mbid=social_retweet"/><meta property="twitter:site" content="@epicurious"/><meta property="twitter:title" content="Epicurious – Recipes, Menu Ideas, Videos &amp; Cooking Tips"/><meta property="pinterest:image" content="https://assets.epicurious.com/photos/656f72061ce0aa7243171bbd/2:3/w_1000,h_1500,c_limit/Champagne-Cocktail_RECIPE_V1.jpg"/><meta property="fb:app_id" content="2309869772"/><meta property="fb:pages" content="12770210203"/><meta name="google" content="nopagereadaloud"/><script id="kendra" type="text/javascript">(()=>{var r=class{constructor(){this.registry={}}register(t,e){if(this.registry[t])throw new Error("Event with key "+t+" already exists.");this.registry[t]=e,Object.defineProperty(this,t,{get(){return this.registry[t]},enumerable:!0,configurable:!1})}delete(t){delete this.registry[t],delete this[t]}get(t){let e=this.registry[t];if(!e)throw new Error("Event with key "+t+" is not registered.");return e}};(function(){let n=new r;window.Kendra=n})();})();</script><link rel="canonical" href="https://www.epicurious.com/"/><link rel="alternate" type="application/rss+xml" href="htt ...
# .cbdLXO{margin:0;text-align:center;}/*!sc*/
# .ftUkBG{margin:0;text-align:left;}/*!sc*/
# .ggJISK{margin:0;margin-bottom:3.5rem;}/*!sc*/
# data-styled.g1[id="BaseWrap-sc-gzmcOU"]{content:"deqABF,cbdLXO,ftUkBG,ggJISK,"}/*!sc*/
# .dVfXDd{--type-token:consumptionEditorial.body-core;text-transform:none;font-family:STIXTwoText ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.00588235302883036em;-moz-letter-spacing:0.00588235302883036em;-ms-letter-spacing:0.00588235302883036em;letter-spacing:0.00588235302883036em;line-break:auto;line-height:1.69em;font-size:17px;font-weight:400;overflow-wrap:normal;color:rgba(201,201,201,1);}/*!sc*/
# .dVfXDd a{color:inherit;}/*!sc*/
# .ijWuNu{--type-token:consumptionEditorial.body-core;text-transform:none;font-family:STIXTwoText ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.00588235302883036em;-moz-letter-spacing:0.00588235302883036em;-ms-letter-spacing:0.00588235302883036em;letter-spacing:0.00588235302883036em;line-break:auto;line-height:1.69em;font-size:17px;font-weight:400;overflow-wrap:normal;color:rgba(51,51,51,1);}/*!sc*/
# .ijWuNu a{color:inherit;}/*!sc*/
# .kjcnEi{--type-token:discovery.subhed-section-primary;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.09615384615384616em;-moz-letter-spacing:0.09615384615384616em;-ms-letter-spacing:0.09615384615384616em;letter-spacing:0.09615384615384616em;line-break:auto;line-height:1.229999982393705em;font-size:26px;font-weight:500;overflow-wrap:normal;color:rgba(51,51,51,1);}/*!sc*/
# @media (min-width:768px){.kjcnEi{font-size:24px;line-height:1.0833333333333333em;}}/*!sc*/
# .kjcnEi a{color:inherit;}/*!sc*/
# .gNRPUh{--type-token:discovery.hed-core-secondary;text-transform:none;font-family:SourceSerif ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.4099999596090877em;font-size:17px;font-weight:700;overflow-wrap:normal;color:rgba(51,51,51,1);}/*!sc*/
# @media (min-width:768px){.gNRPUh{font-size:20.399999618530273px;line-height:1.4098039591509492em;}}/*!sc*/
# .gNRPUh a{color:inherit;}/*!sc*/
# .hdGJiy{--type-token:discovery.description-core;text-transform:none;font-family:STIXTwoText ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.4699999491373699em;font-size:15px;font-weight:400;overflow-wrap:normal;color:rgba(80,80,80,1);}/*!sc*/
# .hdGJiy a{color:inherit;}/*!sc*/
# .fmWmyQ{--type-token:globalEditorial.numerical-large;text-transform:none;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.1699999968210857em;font-size:24px;font-weight:700;overflow-wrap:normal;color:rgba(80,80,80,1);}/*!sc*/
# .fmWmyQ a{color:inherit;}/*!sc*/
# .fINpWU{--type-token:globalEditorial.context-primary;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:500;overflow-wrap:normal;color:rgba(117,117,117,1);}/*!sc*/
# .fINpWU a{color:inherit;}/*!sc*/
# data-styled.g2[id="BaseText-eqOrNE"]{content:"dVfXDd,ijWuNu,kjcnEi,gNRPUh,hdGJiy,fmWmyQ,fINpWU,"}/*!sc*/
# .cLqibi{color:rgba(201,201,201,1);-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:5s;transition-duration:5s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;color:rgba(51,51,51,1);cursor:pointer;-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;}/*!sc*/
# .cLqibi:link{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(51,51,51,1);}/*!sc*/
# .cLqibi:visited{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(51,51,51,1);}/*!sc*/
# .cLqibi:hover{color:rgba(51,51,51,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .cLqibi:active{color:rgba(51,51,51,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .cLqibi:focus{color:rgba(51,51,51,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hsENAC{color:rgba(201,201,201,1);-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:5s;transition-duration:5s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;--type-token:foundation.link-primary;text-transform:none;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.07099999984105428em;-moz-letter-spacing:0.07099999984105428em;-ms-letter-spacing:0.07099999984105428em;letter-spacing:0.07099999984105428em;line-break:auto;line-height:1.4200000762939453em;font-size:14px;font-weight:500;overflow-wrap:normal;color:rgba(51,51,51,1);cursor:pointer;-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;}/*!sc*/
# .hsENAC:link{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(51,51,51,1);}/*!sc*/
# .hsENAC:visited{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(51,51,51,1);}/*!sc*/
# .hsENAC:hover{color:rgba(235,0,0,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hsENAC:active{color:rgba(235,0,0,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hsENAC:focus{color:rgba(235,0,0,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .fkcGxl{color:rgba(51,51,51,1);-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:5s;transition-duration:5s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;color:rgba(51,51,51,1);cursor:pointer;-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;}/*!sc*/
# .fkcGxl:link{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(51,51,51,1);}/*!sc*/
# .fkcGxl:visited{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(51,51,51,1);}/*!sc*/
# .fkcGxl:hover{color:rgba(51,51,51,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .fkcGxl:active{color:rgba(51,51,51,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .fkcGxl:focus{color:rgba(51,51,51,1);-webkit-text-decoration:undefined;text-decoration:undefined;}/*!sc*/
# data-styled.g3[id="BaseLink-eTpkqh"]{content:"cLqibi,hsENAC,fkcGxl,"}/*!sc*/
# .frFMjA{display:inline-block;background-color:rgba(201,201,201,1);cursor:pointer;text-align:center;-webkit-text-decoration:none;text-decoration:none;-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# .frFMjA:disabled{pointer-events:none;}/*!sc*/
# .frFMjA:hover,.frFMjA:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g4[id="BaseButton-lbLhfD"]{content:"frFMjA,"}/*!sc*/
# .jDxUnC{border:1px solid rgba(51,51,51,1);padding:0.125em 0.5rem;}/*!sc*/
# .jDxUnC[disabled]{pointer-events:none;}/*!sc*/
# .jDxUnC[type='checkbox']{position:absolute;top:0;right:0;bottom:0;left:0;visibility:initial;opacity:0;margin:0;cursor:inherit;padding:0;width:100%;height:100%;}/*!sc*/
# .jDxUnC[type='radio']{position:absolute;top:0;right:0;bottom:0;left:0;visibility:initial;opacity:0;margin:0;cursor:inherit;padding:0;width:100%;height:100%;}/*!sc*/
# .jDxUnC[type='submit']{display:inline-block;background-color:rgba(201,201,201,1);cursor:pointer;text-align:center;-webkit-text-decoration:none;text-decoration:none;-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# .jDxUnC[type='submit']:disabled{pointer-events:none;}/*!sc*/
# .jDxUnC[type='submit']:hover,.jDxUnC[type='submit']:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .jDxUnC[type='reset']{cursor:pointer;}/*!sc*/
# .jDxUnC[type='number']::-webkit-inner-spin-button{height:auto;}/*!sc*/
# .jDxUnC[type='number']::-webkit-outer-spin-button{height:auto;}/*!sc*/
# .jDxUnC[type='search']{box-sizing:border-box;}/*!sc*/
# data-styled.g5[id="BaseInput-fFSJlf"]{content:"jDxUnC,"}/*!sc*/
# .fWZsjA{display:block;width:100%;}/*!sc*/
# data-styled.g11[id="RowWrapper-EQDhp"]{content:"fWZsjA,"}/*!sc*/
# .ipyZZT{width:100%;}/*!sc*/
# .ipyZZT .icon-close{padding:8px;}/*!sc*/
# .ipyZZT .cns-ads-slot-state-filled.cns-ads-slot-type-hero{padding:8px 0;}/*!sc*/
# data-styled.g12[id="StickyHeroAdWrapper-eTeAbx"]{content:"ipyZZT,"}/*!sc*/
# .ddFpqJ.ddFpqJ.ad.should-hold-space{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;min-height:66px;}/*!sc*/
# @media (min-width:768px){.ddFpqJ.ddFpqJ.ad.should-hold-space{min-height:106px;}}/*!sc*/
# data-styled.g14[id="AdWrapper-efOWgS"]{content:"ddFpqJ,"}/*!sc*/
# .bpsHTm{padding-top:var(--header-height,56px);}/*!sc*/
# data-styled.g15[id="AdsSpacer-fqJTPo"]{content:"bpsHTm,"}/*!sc*/
# @media (max-width:768px){.jjLMxv{min-height:calc( ( 100px - 50px - 16px ) / 2 );}}/*!sc*/
# data-styled.g16[id="SpaceHolder-lkqTPQ"]{content:"jjLMxv,"}/*!sc*/
# .jlFMVt{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;z-index:1;border-radius:0px;padding:1rem;min-width:auto;height:auto;min-height:auto;-webkit-transition-property:color,background,border;transition-property:color,background,border;-webkit-transition-duration:200ms;transition-duration:200ms;-webkit-transition-timing-function:ease-in;transition-timing-function:ease-in;color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);--type-token:utility.button-utility;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;}/*!sc*/
# .jlFMVt .spinner{-webkit-transform:scale(1.125);-ms-transform:scale(1.125);transform:scale(1.125);-webkit-animation-name:spin;animation-name:spin;-webkit-animation-duration:1200ms;animation-duration:1200ms;-webkit-animation-timing-function:linear;animation-timing-function:linear;-webkit-animation-iteration-count:infinite;animation-iteration-count:infinite;}/*!sc*/
# .jlFMVt .spinner path{fill:black;}/*!sc*/
# @-webkit-keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}to{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# @keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}to{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# .jlFMVt.button--utility + .ButtonWrapper-igqDZ.button--utility{margin-top:1rem;}/*!sc*/
# .jlFMVt.button__icon--chevron-down .button-icon{-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# .jlFMVt.button__icon--chevron-up .button-icon{-webkit-transform:rotate(270deg);-ms-transform:rotate(270deg);transform:rotate(270deg);}/*!sc*/
# @media (min-width:768px){.jlFMVt{min-width:auto;}}/*!sc*/
# .jlFMVt:hover{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jlFMVt:focus{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jlFMVt:focus-visible{outline:3px solid #0066cc;outline-offset:3px;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jlFMVt:active{outline:none;}/*!sc*/
# .jlFMVt:active.ButtonWrapper-igqDZ:active{border-color:rgba(0,0,0,0.2);}/*!sc*/
# .jlFMVt:active::before{position:absolute;z-index:-1;width:100%;height:100%;content:'';}/*!sc*/
# .jlFMVt:active{outline:none;}/*!sc*/
# .jlFMVt:hover{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .jlFMVt:focus{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .jlFMVt:active{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .jlFMVt:disabled,.jlFMVt[aria-disabled='true'],.jlFMVt.jlFMVt[aria-disabled='true']:focus,.jlFMVt.jlFMVt[aria-disabled='true']:active{cursor:default;pointer-events:none;color:rgba(255,255,255,1);border-color:rgba(201,201,201,1);border-width:2px;border-style:solid;background-color:rgba(201,201,201,1);}/*!sc*/
# .dRemWM{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;z-index:1;border-radius:0px;padding:1rem;min-width:auto;height:auto;min-height:auto;-webkit-transition-property:color,background,border;transition-property:color,background,border;-webkit-transition-duration:200ms;transition-duration:200ms;-webkit-transition-timing-function:ease-in;transition-timing-function:ease-in;color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);--type-token:utility.button-core;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;}/*!sc*/
# .dRemWM .spinner{-webkit-transform:scale(1.125);-ms-transform:scale(1.125);transform:scale(1.125);-webkit-animation-name:spin;animation-name:spin;-webkit-animation-duration:1200ms;animation-duration:1200ms;-webkit-animation-timing-function:linear;animation-timing-function:linear;-webkit-animation-iteration-count:infinite;animation-iteration-count:infinite;}/*!sc*/
# .dRemWM .spinner path{fill:black;}/*!sc*/
# @-webkit-keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}to{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# @keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}to{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# .dRemWM.button--utility + .ButtonWrapper-igqDZ.button--utility{margin-top:1rem;}/*!sc*/
# .dRemWM.button__icon--chevron-down .button-icon{-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# .dRemWM.button__icon--chevron-up .button-icon{-webkit-transform:rotate(270deg);-ms-transform:rotate(270deg);transform:rotate(270deg);}/*!sc*/
# @media (min-width:768px){.dRemWM{min-width:auto;}}/*!sc*/
# .dRemWM:hover{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dRemWM:focus{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dRemWM:focus-visible{outline:3px solid #0066cc;outline-offset:3px;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dRemWM:active{outline:none;}/*!sc*/
# .dRemWM:active.ButtonWrapper-igqDZ:active{border-color:rgba(255,255,255,0.2);}/*!sc*/
# .dRemWM:active::before{position:absolute;z-index:-1;width:100%;height:100%;content:'';}/*!sc*/
# .dRemWM:active{outline:none;}/*!sc*/
# .dRemWM:hover{color:rgba(255,255,255,1);border-color:rgba(192,57,57,1);border-width:2px;border-style:solid;background-color:rgba(192,57,57,1);}/*!sc*/
# .dRemWM:focus{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .dRemWM:active{color:rgba(255,255,255,1);border-color:rgba(192,57,57,1);border-width:2px;border-style:solid;background-color:rgba(192,57,57,1);}/*!sc*/
# .dRemWM:disabled,.dRemWM[aria-disabled='true'],.dRemWM.dRemWM[aria-disabled='true']:focus,.dRemWM.dRemWM[aria-disabled='true']:active{cursor:default;pointer-events:none;color:rgba(255,255,255,1);border-color:rgba(201,201,201,1);border-width:2px;border-style:solid;background-color:rgba(201,201,201,1);}/*!sc*/
# .kQBHiR{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;position:relative;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;z-index:1;border-radius:0px;padding:1rem;min-width:auto;height:auto;min-height:auto;-webkit-transition-property:color,background,border;transition-property:color,background,border;-webkit-transition-duration:200ms;transition-duration:200ms;-webkit-transition-timing-function:ease-in;transition-timing-function:ease-in;color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);--type-token:utility.button-utility;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;}/*!sc*/
# .kQBHiR .spinner{-webkit-transform:scale(1.125);-ms-transform:scale(1.125);transform:scale(1.125);-webkit-animation-name:spin;animation-name:spin;-webkit-animation-duration:1200ms;animation-duration:1200ms;-webkit-animation-timing-function:linear;animation-timing-function:linear;-webkit-animation-iteration-count:infinite;animation-iteration-count:infinite;}/*!sc*/
# .kQBHiR .spinner path{fill:black;}/*!sc*/
# @-webkit-keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}to{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# @keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}to{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# .kQBHiR.button--utility + .ButtonWrapper-igqDZ.button--utility{margin-top:1rem;}/*!sc*/
# .kQBHiR.button__icon--chevron-down .button-icon{-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# .kQBHiR.button__icon--chevron-up .button-icon{-webkit-transform:rotate(270deg);-ms-transform:rotate(270deg);transform:rotate(270deg);}/*!sc*/
# @media (min-width:768px){.kQBHiR{min-width:auto;}}/*!sc*/
# .kQBHiR:hover{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .kQBHiR:focus{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .kQBHiR:focus-visible{outline:3px solid #0066cc;outline-offset:3px;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .kQBHiR:active{outline:none;}/*!sc*/
# .kQBHiR:active.ButtonWrapper-igqDZ:active{border-color:rgba(0,0,0,0.2);}/*!sc*/
# .kQBHiR:active::before{position:absolute;z-index:-1;width:100%;height:100%;content:'';}/*!sc*/
# .kQBHiR:active{outline:none;}/*!sc*/
# .kQBHiR:hover{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .kQBHiR:focus{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .kQBHiR:active{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .kQBHiR:disabled,.kQBHiR[aria-disabled='true'],.kQBHiR.kQBHiR[aria-disabled='true']:focus,.kQBHiR.kQBHiR[aria-disabled='true']:active{cursor:default;pointer-events:none;color:rgba(255,255,255,1);border-color:rgba(201,201,201,1);border-width:2px;border-style:solid;background-color:rgba(201,201,201,1);}/*!sc*/
# data-styled.g17[id="ButtonWrapper-igqDZ"]{content:"jlFMVt,dRemWM,kQBHiR,"}/*!sc*/
# .hvohFn{font-variant-ligatures:none;padding:0.5rem 0;position:absolute;margin:0;border:0;padding:0;width:1px;height:1px;overflow:hidden;-webkit-clip:rect(0 0 0 0);clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);white-space:nowrap;}/*!sc*/
# data-styled.g18[id="ButtonLabel-cyWivE"]{content:"hvohFn,"}/*!sc*/
# .bQqPLN{padding-right:0;padding-left:0;}/*!sc*/
# data-styled.g19[id="ButtonIconWrapper-gzKJtq"]{content:"bQqPLN,"}/*!sc*/
# .jKYSoZ{display:block;width:32px;height:32px;}/*!sc*/
# data-styled.g21[id="ButtonIcon-bdIQNJ"]{content:"jKYSoZ,"}/*!sc*/
# .jUhiFc.jUhiFc{--grid-gap:1rem;--grid-margin:1.5rem;gap:var(--grid-gap);padding-right:calc(1 * var(--grid-margin));padding-left:calc(1 * var(--grid-margin));margin:0 auto;width:100%;max-width:1600px;}/*!sc*/
# @media (min-width:768px){.jUhiFc.jUhiFc{--grid-gap:1.5rem;--grid-margin:3rem;}}/*!sc*/
# @media (min-width:1024px){.jUhiFc.jUhiFc{--grid-gap:2rem;}}/*!sc*/
# @media (min-width:1280px){.jUhiFc.jUhiFc{--grid-margin:4rem;}}/*!sc*/
# .jUhiFc.jUhiFc .newsletter-plp-full-bleed{display:grid;grid-column:1/-1;}/*!sc*/
# @media (max-width:1024px){}/*!sc*/
# @media (min-width:768px){.jUhiFc.jUhiFc{grid-template-columns:repeat(12,1fr);}}/*!sc*/
# .jUhiFc.jUhiFc.jUhiFc.jUhiFc{display:block;grid-template-columns:unset;}/*!sc*/
# .fubVbh.fubVbh{--grid-gap:1rem;--grid-margin:1.5rem;display:grid;grid-template-columns:repeat(4,1fr);gap:var(--grid-gap);padding-right:calc(1 * var(--grid-margin));padding-left:calc(1 * var(--grid-margin));margin:0 auto;width:100%;max-width:1600px;}/*!sc*/
# @media (min-width:768px){.fubVbh.fubVbh{--grid-gap:1.5rem;--grid-margin:3rem;}}/*!sc*/
# @media (min-width:1024px){.fubVbh.fubVbh{--grid-gap:2rem;}}/*!sc*/
# @media (min-width:1280px){.fubVbh.fubVbh{--grid-margin:4rem;}}/*!sc*/
# .fubVbh.fubVbh .newsletter-plp-full-bleed{display:grid;grid-column:1/-1;}/*!sc*/
# @media (max-width:1024px){}/*!sc*/
# @media (min-width:768px){.fubVbh.fubVbh{grid-template-columns:repeat(12,1fr);}}/*!sc*/
# .bSEvzF.bSEvzF{--grid-gap:1rem;--grid-margin:1.5rem;display:grid;grid-template-columns:repeat(4,1fr);gap:var(--grid-gap);padding-right:calc(1 * var(--grid-margin));padding-left:calc(1 * var(--grid-margin));margin:0 auto;width:100%;max-width:1600px;}/*!sc*/
# @media (min-width:768px){.bSEvzF.bSEvzF{--grid-gap:1.5rem;--grid-margin:3rem;}}/*!sc*/
# @media (min-width:1024px){.bSEvzF.bSEvzF{--grid-gap:2rem;}}/*!sc*/
# @media (min-width:1280px){.bSEvzF.bSEvzF{--grid-margin:4rem;}}/*!sc*/
# .bSEvzF.bSEvzF .newsletter-plp-full-bleed{display:grid;grid-column:1/-1;}/*!sc*/
# @media (max-width:1024px){}/*!sc*/
# @media (min-width:768px){.bSEvzF.bSEvzF{grid-template-columns:repeat(12,1fr);}}/*!sc*/
# @media (min-width:1024px) and (max-width:1045px){.bSEvzF.bSEvzF{grid-template-columns:repeat(8,1fr) minmax(300px,4fr);}}/*!sc*/
# @media (min-width:1280px) and (max-width:1393px){.bSEvzF.bSEvzF{grid-template-columns:repeat(9,1fr) minmax(300px,3fr);}}/*!sc*/
# .crAyIs.crAyIs{--grid-gap:1rem;--grid-margin:1.5rem;display:grid;grid-template-columns:repeat(4,1fr);gap:var(--grid-gap);margin:0 auto;width:100%;max-width:1600px;}/*!sc*/
# @media (min-width:768px){.crAyIs.crAyIs{--grid-gap:1.5rem;--grid-margin:3rem;}}/*!sc*/
# @media (min-width:1024px){.crAyIs.crAyIs{--grid-gap:2rem;}}/*!sc*/
# @media (min-width:1280px){.crAyIs.crAyIs{--grid-margin:4rem;}}/*!sc*/
# .crAyIs.crAyIs .newsletter-plp-full-bleed{display:grid;grid-column:1/-1;}/*!sc*/
# @media (max-width:1024px){}/*!sc*/
# @media (min-width:768px){.crAyIs.crAyIs{grid-template-columns:repeat(12,1fr);}}/*!sc*/
# data-styled.g25[id="GridWrapper-cFSKbf"]{content:"jUhiFc,fubVbh,bSEvzF,crAyIs,"}/*!sc*/
# .iEWjAa{grid-column:1 / -1;}/*!sc*/
# @media (min-width:1024px){.iEWjAa{grid-column:span 8;}}/*!sc*/
# @media (min-width:1280px){.iEWjAa{grid-column:span 9;}}/*!sc*/
# .cNAFhG{display:none;}/*!sc*/
# @media (min-width:1024px){.cNAFhG{display:block;justify-self:start;}}/*!sc*/
# @media (min-width:1280px){.cNAFhG{display:block;}.cNAFhG .ad--rail{max-width:300px;}}/*!sc*/
# @media (min-width:1024px){.cNAFhG{grid-column:9 / -1;}}/*!sc*/
# @media (min-width:1280px){.cNAFhG{grid-column:10 / -1;}}/*!sc*/
# .dORtPa{grid-column:1/-1;}/*!sc*/
# @media (min-width:768px){.dORtPa{grid-column:span 6;}}/*!sc*/
# data-styled.g26[id="GridItem-beYvyV"]{content:"bRelOV,iEWjAa,cNAFhG,dORtPa,"}/*!sc*/
# .gkOnUH{--type-token:utility.input-core;text-transform:none;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.25em;font-size:16px;font-weight:400;overflow-wrap:normal;margin-top:0.5rem;padding:0.5rem 0.75rem;width:100%;text-transform:none;-webkit-transition-property:color,background,border;transition-property:color,background,border;-webkit-transition-duration:200ms;transition-duration:200ms;-webkit-transition-timing-function:ease-in;transition-timing-function:ease-in;background-color:rgba(255,255,255,1);color:rgba(117,117,117,1);border-width:1px;border-style:solid;border-color:rgba(201,201,201,1);border-radius:0;height:3rem;-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# .gkOnUH:focus{outline:0;}/*!sc*/
# .gkOnUH:focus + .TextFieldIcon-fQIYjY svg{fill:rgba(51,51,51,1);}/*!sc*/
# .gkOnUH:active,.gkOnUH:focus{background-color:rgba(255,255,255,1);color:rgba(51,51,51,1);border-width:1px;border-style:solid;border-color:rgba(51,51,51,1);}/*!sc*/
# .gkOnUH[disabled]{background-color:rgba(201,201,201,1);color:rgba(117,117,117,1);border-width:1px;border-style:solid;border-color:rgba(117,117,117,1);}/*!sc*/
# data-styled.g32[id="TextFieldControlInput-eABHcK"]{content:"gkOnUH,"}/*!sc*/
# .ckirip .TextFieldIcon-fQIYjY svg{fill:rgba(117,117,117,1);pointer-events:none;}/*!sc*/
# data-styled.g35[id="TextFieldLabel-jVWkJp"]{content:"ckirip,"}/*!sc*/
# .diAzpa{position:relative;grid-column:1;}/*!sc*/
# .diAzpa input[type='search']{-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# data-styled.g36[id="TextFieldInputContainer-iXtYZG"]{content:"diAzpa,"}/*!sc*/
# .cNiSue{display:grid;margin-bottom:1rem;}/*!sc*/
# @media (min-width:768px){}/*!sc*/
# .cNiSue::-webkit-input-placeholder{--color__token-name:colors.interactive.base.dark;color:rgba(117,117,117,1);}/*!sc*/
# .cNiSue::-moz-placeholder{--color__token-name:colors.interactive.base.dark;color:rgba(117,117,117,1);}/*!sc*/
# .cNiSue:-ms-input-placeholder{--color__token-name:colors.interactive.base.dark;color:rgba(117,117,117,1);}/*!sc*/
# .cNiSue::placeholder{--color__token-name:colors.interactive.base.dark;color:rgba(117,117,117,1);}/*!sc*/
# data-styled.g41[id="TextFieldWrapper-KgniU"]{content:"cNiSue,"}/*!sc*/
# .eHOOfj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:100%;height:100%;}/*!sc*/
# .eHOOfj .icon{width:100%;height:100%;}/*!sc*/
# .eHOOfj .icon-shopping{width:initial;height:initial;}/*!sc*/
# data-styled.g56[id="SocialIconViewBox-eHrlQI"]{content:"eHOOfj,"}/*!sc*/
# .fuiLqy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:32px;width:32px;}/*!sc*/
# .fuiLqy.fuiLqy.fuiLqy.fuiLqy .icon{-webkit-transform:none;-ms-transform:none;transform:none;width:100%;height:100%;}/*!sc*/
# data-styled.g57[id="SocialIconContainer-hAqqbX"]{content:"fuiLqy,"}/*!sc*/
# .achyN{-webkit-text-decoration:none;text-decoration:none;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:3rem;height:3rem;}/*!sc*/
# .achyN:hover,.achyN:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .achyN path{--fill__token-name:colors.foundation.footer.links.primary;fill:rgba(255,255,255,1);}/*!sc*/
# .achyN:hover path{--fill__token-name:colors.foundation.footer.social.hover;fill:rgba(226,221,204,1);}/*!sc*/
# data-styled.g58[id="SocialIconExternalLink-hzNpWp"]{content:"achyN,"}/*!sc*/
# .iCoXyS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;gap:1rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:0;margin-bottom:0;margin-left:-1rem;padding-left:0;list-style:none;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-left:0rem;}/*!sc*/
# @media (min-width:1024px){.iCoXyS{-webkit-box-pack:start;-webkit-justify-content:start;-ms-flex-pack:start;justify-content:start;}}/*!sc*/
# data-styled.g60[id="SocialIconsList-cNoJPV"]{content:"iCoXyS,"}/*!sc*/
# .gmnjub{false;}/*!sc*/
# @media (min-width:320px){.gmnjub{-webkit-box-pack:start;-webkit-justify-content:start;-ms-flex-pack:start;justify-content:start;}}/*!sc*/
# data-styled.g61[id="SocialIconsWrapper-iaisJM"]{content:"gmnjub,"}/*!sc*/
# .dugjwV .icon-bookmark path{-webkit-transition:all 0.2s ease-in-out;transition:all 0.2s ease-in-out;}/*!sc*/
# data-styled.g62[id="SocialIconNetworkIconComponent-dowysq"]{content:"dugjwV,"}/*!sc*/
# .gNSsSY{--type-token:utility.button-core;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:24px 0 32px 0;border-color:white;background:rgba(51,51,51,0.08);padding:17px 20px;--color__token-name:colors.interactive.base.black;color:rgba(51,51,51,1);-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:14px 16px;width:48px;margin:0px;}/*!sc*/
# .gNSsSY:hover{--type-token:utility.button-core;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;border-color:white;background:rgba(51,51,51,0.3);--color__token-name:colors.interactive.base.black;color:rgba(51,51,51,1);}/*!sc*/
# .gNSsSY:focus{--type-token:utility.button-core;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;border-color:white;background:rgba(51,51,51,0.3);--color__token-name:colors.interactive.base.black;color:rgba(51,51,51,1);}/*!sc*/
# .gNSsSY:active{--type-token:utility.button-core;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;border-color:white;background:rgba(51,51,51,0.08);--color__token-name:colors.interactive.base.black;color:rgba(51,51,51,1);}/*!sc*/
# @media (min-width:768px){.gNSsSY{display:none;}}/*!sc*/
# data-styled.g63[id="SocialIconButton-dpYFeu"]{content:"gNSsSY,"}/*!sc*/
# .jwYQWO{display:inline-block;position:relative;width:-webkit-fill-available;width:-moz-available;width:fill-available;}/*!sc*/
# data-styled.g74[id="ResponsiveImagePicture-cGZhnX"]{content:"jwYQWO,"}/*!sc*/
# .koTknX{display:block;-webkit-transition:opacity 1s;transition:opacity 1s;opacity:1;overflow:hidden;}/*!sc*/
# data-styled.g110[id="SpanWrapper-zEXFr"]{content:"koTknX,"}/*!sc*/
# @media (max-width:767px){.ikOINK::before{content:'';display:block;padding-top:min(100%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# @media (min-width:768px){.ikOINK::before{content:'';display:block;padding-top:min(100%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# .ikOINK > .aspect-ratio--overlay-container{bottom:0;left:0;overflow:hidden;position:absolute;right:0;top:0;}/*!sc*/
# @media (max-width:767px){.eJpBwO::before{content:'';display:block;padding-top:min(66.66666666666666%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# @media (min-width:768px){.eJpBwO::before{content:'';display:block;padding-top:min(66.66666666666666%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# .eJpBwO > .aspect-ratio--overlay-container{bottom:0;left:0;overflow:hidden;position:absolute;right:0;top:0;}/*!sc*/
# @media (max-width:767px){.cErxRK::before{content:'';display:block;padding-top:min(56.25%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# @media (min-width:768px){.cErxRK::before{content:'';display:block;padding-top:min(56.25%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# .cErxRK > .aspect-ratio--overlay-container{bottom:0;left:0;overflow:hidden;position:absolute;right:0;top:0;}/*!sc*/
# @media (max-width:767px){.dKhhoi::before{content:'';display:block;padding-top:min(133.33333333333331%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# @media (min-width:768px){.dKhhoi::before{content:'';display:block;padding-top:min(133.33333333333331%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# .dKhhoi > .aspect-ratio--overlay-container{bottom:0;left:0;overflow:hidden;position:absolute;right:0;top:0;}/*!sc*/
# data-styled.g161[id="AspectRatioContainer-bEozCe"]{content:"ikOINK,eJpBwO,cErxRK,dKhhoi,"}/*!sc*/
# .ifVTHa{margin-left:0.5rem;}/*!sc*/
# data-styled.g182[id="RatingRatings-gXBeiH"]{content:"ifVTHa,"}/*!sc*/
# .fPHLgP.fPHLgP.fPHLgP{position:absolute;top:7px;left:7px;width:18px;height:18px;}/*!sc*/
# .fPHLgP.fPHLgP.fPHLgP path{--fill__token-name:colors.interactive.base.brand-primary;fill:rgba(51,51,51,1);}/*!sc*/
# .ihrDUu.ihrDUu.ihrDUu{position:absolute;top:7px;left:7px;width:18px;height:18px;}/*!sc*/
# .ihrDUu.ihrDUu.ihrDUu path{--fill__token-name:colors.interactive.base.brand-primary;fill:rgba(51,51,51,1);}/*!sc*/
# .ihrDUu.ihrDUu.ihrDUu.ihrDUu.ihrDUu.ihrDUu path:nth-of-type(1){--fill__token-name:colors.interactive.base.brand-primary;fill:rgba(51,51,51,1);}/*!sc*/
# data-styled.g183[id="RatingStarHalf-kKVCTE"]{content:"fPHLgP,ihrDUu,"}/*!sc*/
# .jofiAG{position:relative;width:32px;height:32px;}/*!sc*/
# data-styled.g184[id="RatingStar-bDVkyb"]{content:"jofiAG,"}/*!sc*/
# .iobXOd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# data-styled.g185[id="RatingStars-iURqAQ"]{content:"iobXOd,"}/*!sc*/
# .IfkO.IfkO.IfkO{all:unset;cursor:pointer;}/*!sc*/
# .IfkO.IfkO.IfkO::before{content:none;}/*!sc*/
# .IfkO.IfkO.IfkO::after{content:none;}/*!sc*/
# data-styled.g186[id="RatingLabel-cTXwMB"]{content:"IfkO,"}/*!sc*/
# .fzuyjx.fzuyjx.fzuyjx{all:unset;position:absolute;margin:0;border:0;padding:0;width:1px;height:1px;overflow:hidden;-webkit-clip:rect(0 0 0 0);clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);white-space:nowrap;}/*!sc*/
# .fzuyjx.fzuyjx.fzuyjx:disabled + .RatingLabel-cTXwMB{cursor:pointer;}/*!sc*/
# .fzuyjx.fzuyjx.fzuyjx:focus + .RatingLabel-cTXwMB{outline:#2360c5 auto 1px;}/*!sc*/
# .weCTb.weCTb.weCTb{all:unset;position:absolute;margin:0;border:0;padding:0;width:1px;height:1px;overflow:hidden;-webkit-clip:rect(0 0 0 0);clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);white-space:nowrap;}/*!sc*/
# .weCTb.weCTb.weCTb + .RatingLabel-cTXwMB ~ .RatingLabel-cTXwMB .RatingStarHalf-kKVCTE path{--fill__token-name:colors.interactive.base.light;fill:rgba(201,201,201,1);}/*!sc*/
# .weCTb.weCTb.weCTb:disabled + .RatingLabel-cTXwMB{cursor:pointer;}/*!sc*/
# .weCTb.weCTb.weCTb:focus + .RatingLabel-cTXwMB{outline:#2360c5 auto 1px;}/*!sc*/
# data-styled.g187[id="RatingInput-ccHABN"]{content:"fzuyjx,weCTb,"}/*!sc*/
# .fgPsvs{margin-right:0.5rem;}/*!sc*/
# data-styled.g189[id="RatingRating-bJravU"]{content:"fgPsvs,"}/*!sc*/
# .fBJMkW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g190[id="RatingFormWrapper-bmbFgi"]{content:"fBJMkW,"}/*!sc*/
# .hmNReC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:1.5rem 0 2rem;width:100%;}/*!sc*/
# data-styled.g191[id="RatingWrapper-bWyTJA"]{content:"hmNReC,"}/*!sc*/
# .dXwrHB{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;position:absolute;bottom:0.5rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-transition:background 200ms ease;transition:background 200ms ease;border:0;border-radius:50%;background:rgba( 255,255,255, 0.85 );padding:0;width:48px;height:48px;left:0.5rem;}/*!sc*/
# .dXwrHB .ButtonIconWrapper-gzKJtq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .dXwrHB .ButtonIconWrapper-gzKJtq .ButtonIcon-bdIQNJ{margin-left:2px;width:auto;height:auto;}/*!sc*/
# .dXwrHB .icon{--fill__token-name:colors.interactive.base.black;fill:rgba(51,51,51,1);}/*!sc*/
# .dXwrHB:hover,.dXwrHB:active,.dXwrHB:focus{border:0;background:rgba( 255,255,255, 0.85 );}/*!sc*/
# data-styled.g198[id="InlineVideoItemIconButton-kbRQes"]{content:"dXwrHB,"}/*!sc*/
# .jxeESw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;margin-top:0.5rem;}/*!sc*/
# .jxeESw .button__icon-container{margin-left:auto;cursor:pointer;}/*!sc*/
# .jxeESw .SocialIconButton-dpYFeu{display:contents;}/*!sc*/
# .jxeESw .SocialIconButton-dpYFeu .icon-bookmark{padding:3px;width:1.5rem;height:1.5rem;}/*!sc*/
# data-styled.g200[id="UtilityFeaturesWrapper-eNKivI"]{content:"jxeESw,"}/*!sc*/
# .ftRvdL{position:relative;}/*!sc*/
# data-styled.g203[id="ImageWrapper-chXNAU"]{content:"ftRvdL,"}/*!sc*/
# .deWMOT{border-radius:8px;padding:1rem 0.25rem 0.5rem;}/*!sc*/
# @media (min-width:768px){.deWMOT{border-radius:16px;padding:1.5rem 0.5rem 0.5rem;}}/*!sc*/
# @media (min-width:1024px){.deWMOT{border-radius:20px;}}/*!sc*/
# data-styled.g204[id="ContentWrapper-bCkkJm"]{content:"deWMOT,"}/*!sc*/
# .yjlRJ{padding:0 0 1rem;}/*!sc*/
# data-styled.g205[id="Content-ifkqHN"]{content:"yjlRJ,"}/*!sc*/
# .ffDePc{cursor:pointer;}/*!sc*/
# data-styled.g206[id="StackedRatingsCardWrapper-ghvskg"]{content:"ffDePc,"}/*!sc*/
# .bVFNUa img{border-radius:8px;width:-webkit-fill-available;width:-moz-available;width:fill-available;}/*!sc*/
# @media (min-width:768px){.bVFNUa img{border-radius:16px;width:-webkit-fill-available;width:-moz-available;width:fill-available;}}/*!sc*/
# @media (min-width:1024px){.bVFNUa img{border-radius:16px;width:-webkit-fill-available;width:-moz-available;width:fill-available;}}/*!sc*/
# data-styled.g208[id="Image-bQSkvr"]{content:"bVFNUa,"}/*!sc*/
# .hIjmI .SkeletonScreenWrapper-fXVbem{margin:0.5rem 0;}/*!sc*/
# data-styled.g210[id="Body-hsMkus"]{content:"hIjmI,"}/*!sc*/
# .fEQvtj{display:inline;margin:0 0 0.5rem;}/*!sc*/
# data-styled.g211[id="Hed-gQCsFV"]{content:"fEQvtj,"}/*!sc*/
# .iIPzBh{margin:0.5rem 0 0;}/*!sc*/
# data-styled.g212[id="Dek-eHIsq"]{content:"iIPzBh,"}/*!sc*/
# .eFPnQC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:2rem;display:block;}/*!sc*/
# .eFPnQC .SocialIconContainer-hAqqbX{height:1.1rem;}/*!sc*/
# .eFPnQC .SocialIconButton-dpYFeu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:auto;border:0;background:none;padding:0;width:1.25rem;list-style:none;}/*!sc*/
# .eFPnQC .SocialIconButton-dpYFeu .icon-bookmark.icon{height:1.25rem;}/*!sc*/
# .eFPnQC .SkeletonScreenWrapper-fXVbem{margin-right:0.125rem;}/*!sc*/
# .eFPnQC .SkeletonScreenWrapper-fXVbem:last-child{margin-left:auto;}/*!sc*/
# .fRIzEv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:2rem;}/*!sc*/
# .fRIzEv .SocialIconContainer-hAqqbX{height:1.1rem;}/*!sc*/
# .fRIzEv .SocialIconButton-dpYFeu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:auto;border:0;background:none;padding:0;width:1.25rem;list-style:none;}/*!sc*/
# .fRIzEv .SocialIconButton-dpYFeu .icon-bookmark.icon{height:1.25rem;}/*!sc*/
# .fRIzEv .SkeletonScreenWrapper-fXVbem{margin-right:0.125rem;}/*!sc*/
# .fRIzEv .SkeletonScreenWrapper-fXVbem:last-child{margin-left:auto;}/*!sc*/
# data-styled.g213[id="MetaData-bjevUx"]{content:"eFPnQC,fRIzEv,"}/*!sc*/
# ...
#   window._mt_init = { resolve };
# });
#
# window.Martech.then((martech) => {
#   martech.setConfig({
#     // custom behavior for header based authentication
#     authHeaders: () => ({
#       'Authorization': 'Bearer ' + (
#         martech.util.getCookie('CN_token_id') ||
#         martech.util.getCookie('CN_userAuth')
#       )
#     }),
#   });
# });</script><script id="martech-lib-script" src="https://martech.condenastdigital.com/lib/martech.js" async="" defer=""></script><script type="text/javascript" id="journey" src="https://www.epicurious.com/9db59hC12ySaHzjphk3Zxwdq0AzQXGvhrHjk4pw8eDDJsNqI77SL-rQaKGXS905wDuDBSVqBq31iXyrcPw9WWGr_GKo-I5YYgmK-3aD6rtZQCCqIWl5lMwPgLkaRuA_EbKAMU4AA" defer=""></script><script async="" id="gladly-chat-script" data-testid="gladly-chat-script" type="text/javascript">
#             window.gladlyConfig = {
#               appId: 'condenast.com-Epicurious',
#               env: 'PROD'
#             };
#
#             (function (window, document, r, env) {
#               if (!window[r]) {
#                 let initArgs, realInit, pending = [];
#
#                 // Determine CDN based on environment
#                 const cdn =
#                   env !== "PROD" && env
#                     ? env === "STAGING"
#                       ? "https://cdn.gladly.qa/gladly/chat-sdk/widget.js"
#                       : env
#                     : "https://cdn.gladly.com/chat-sdk/widget.js";
#
#                 // Define stub for initialization
#                 window[r] = {
#                   init: function () {
#                     initArgs = arguments;
#                     const proxy = {
#                       then: function (cb) {
#                         pending.push({ type: "t", next: cb });
#                         return proxy;
#                       },
#                       catch: function (cb) {
#                         pending.push({ type: "c", next: cb });
#                         return proxy;
#                       },
#                     };
#                     return proxy;
#                   },
#                 };
#
#                 // Called when the real SDK is loaded
#                 window.__onHelpAppHostReady__ = function (actualSdk) {
#                   delete window.__onHelpAppHostReady__;
#                   window[r] = actualSdk;
#                   window[r].loaderCdn = cdn;
#
#                   if (initArgs) {
#                     let result = actualSdk.init.apply(actualSdk, initArgs);
#                     for (let i = 0; i < pending.length; i++) {
#                       const task = pending[i];
#                       result = task.type === "t"
#                         ? result.then(task.next)
#                         : result.catch(task.next);
#                     }
#                   }
#                 };
#
#                 // Load the SDK script
#                 (function () {
#                   try {
#                     const firstScript = document.getElementsByTagName("script")[0];
#                     const sdkScript = document.createElement("script");
#                     sdkScript.async = true;
#                     sdkScript.src = cdn + "?q=" + new Date().getTime();
#                     firstScript.parentNode.insertBefore(sdkScript, firstScript);
#                   } catch (e) {
#                     // Optionally handle script load errors
#                   }
#                 })();
#               }
#             })(window, document, "Gladly", "PROD");
#           </script><script type="text/javascript" data-testid="growthbook-script">(function (props) {
#         const { userAuthenticated, section, contentType, hasBuyButtons, clientSdkKey, apiHost, enableClient, brandSlug } = props;
#         function extractExperimentData(experiment, result) {
#             return {
#                 experiment_id: experiment.key,
#                 feature_id: result.featureId || '',
#                 variation: result.key,
#                 variation_name: result.name || '',
#                 payload: result.value
#             };
#         }
#         function updateDataLayer(expDataLayer) {
#             if (!Array.isArray(window.dataLayer) ||
#                 typeof window.dataLayer[0] !== 'object' ||
#                 expDataLayer.length === 0) {
#                 return;
#             }
#             const mergeAssignments = (newAssignments = [], existingAssignments = []) => {
#                 const merged = [...existingAssignments];
#                 newAssignments.forEach((newAssignment) => {
#                     const existingIndex = merged.findIndex((existing) => existing.experiment_id === newAssignment.experiment_id);
#                     if (existingIndex >= 0) {
#                         merged[existingIndex] = newAssignment;
#                     }
#                     else {
#                         merged.push(newAssignment);
#                     }
#                 });
#                 return merged;
#             };
#             window.dataLayer[0].experiments = mergeAssignments(expDataLayer, window.dataLayer[0].experiments || []);
#             if (window.cns) {
#                 const { experiments } = window.dataLayer[0];
#                 const { pageContext } = window.cns;
#                 if (experiments && experiments.length) {
#                     pageContext.experiments = formatExperimentsForPageContext(experiments);
#                 }
#             }
#             const kendraGrowthBook = window.Kendra.GROWTHBOOK;
#             if (kendraGrowthBook && kendraGrowthBook.broadcast) {
#                 kendraGrowthBook.broadcast('experiments.assignments.processed');
#             }
#         }
#         function formatExperimentsForPageContext(experiments) {
#             if (!experiments.length) {
#                 return {};
#             }
#             const bucketLabel = [];
#             const experimentLabel = [];
#             const payloadArray = [];
#             experiments.forEach((experiment) => {
#                 const { variation_name, experiment_id, payload } = experiment;
#                 bucketLabel.push(`${variation_name}`);
#                 experimentLabel.push(`${experiment_id}`);
#                 if (Array.isArray(payload)) {
#                     payloadArray.push(...payload);
#                 }
#                 else if (payload) {
#                     payloadArray.push(payload);
#                 }
#             });
#             return {
#                 bucketLabel,
#                 experimentLabel,
#                 payload: payloadArray
#             };
#         }
#         function perfMark(name) {
#             if (typeof window.performance !== 'undefined' &&
#                 typeof window.performance.mark !== 'undefined') {
#                 window.performance.mark(name);
#             }
#         }
#         function perfMeasure(name, startMark, endMark) {
#             if (typeof window.performance !== 'undefined' &&
#                 typeof window.performance.measure !== 'undefined') {
#                 try {
#                     window.performance.measure(name, startMark, endMark);
#                 }
#                 catch (e) {
#                     console.error(`Error setting performance measure: ${e}`);
#                 }
#             }
#         }
#         function getCookie(name) {
#             if (typeof document === 'undefined' || !name) {
#                 return '';
#             }
#             const cookiePieces = document.cookie.split(/;\s?/);
#             let cookieValue = '';
#             for (let i = 0; i < cookiePieces.length; i++) {
#                 const parts = cookiePieces[i].split('=');
#                 if (parts[0] === name) {
#                     cookieValue = decodeURIComponent(parts.slice(1).join('='));
#                     break;
#                 }
#             }
#             return cookieValue;
#         }
#         const isDesktopBrowser = () => {
#             const { userAgent } = navigator;
#             return !/Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i.test(userAgent);
#         };
#         const localStorageXidCleanUp = (prefix, xid) => {
#             if (!xid) {
#                 return;
#             }
#             for (let i = 0; i < localStorage.length; i++) {
#                 const key = window.localStorage.key(i);
#                 if (key && key.startsWith(prefix) && !key.includes(xid)) {
#                     window.localStorage.removeItem(key);
#                 }
#             }
#         };
#         const isMobile = !isDesktopBrowser();
#         const userXid = getCookie('CN_xid');
#         try {
#             const segment = getCookie('CN_segments') || null;
#             const amgUserPartner = getCookie('amg_user_partner') || '';
#             window.growthbook_config = window.growthbook_config || {};
#             const { userAgent } = navigator;
#             window.growthbook_config.attributes = {
#                 userAgent,
#                 id: userXid,
#                 url: window.location.href,
#                 isMobile,
#                 loggedIn: userAuthenticated,
#                 segment,
#                 section,
#                 contentType,
#                 hasBuyButtons,
#                 amgUserPartner
#             };
#             window.growthbook_config.trackingCallback = (experiment, result) => {
#                 const expDataLayer = [];
#                 const experimentData = extractExperimentData(experiment, result);
#                 const currentExp = {
#                     ...experimentData,
#                     status: 'CLIENT_ASSIGNMENT'
#                 };
#                 expDataLayer.push(currentExp);
#                 updateDataLayer(expDataLayer);
#                 perfMark(`gb-script-tracking-end`);
#                 perfMeasure(`gb-script-tracking-finish`, `gb-script-end`, `gb-script-tracking-end`);
#             };
#             window.growthbook_queue = window.growthbook_queue || [];
#             window.growthbook_queue.push((gb) => {
#                 const checkReady = () => {
#                     if (gb.ready) {
#                         perfMark(`gb-script-end`);
#                         perfMeasure(`gb-script-ready`, `gb-script-start`, `gb-script-end`);
#                     }
#                     else {
#                         setTimeout(checkReady, 0);
#                     }
#                 };
#                 checkReady();
#             });
#         }
#         catch (e) {
#             console.error('GrowthBook config setup error:', e);
#         }
#         try {
#             const stickyBrands = ['tatler', 'woi'];
#             const isStickyBucketingEnabled = stickyBrands.includes(brandSlug) && !!userXid;
#             if (isStickyBucketingEnabled) {
#                 localStorageXidCleanUp('gbStickyBuckets__', userXid);
#             }
#             if (clientSdkKey && apiHost && enableClient && userXid) {
#                 const cnDebug = getCookie('cn-debug') || false;
#                 const s = document.createElement('script');
#                 s.async = true;
#                 s.dataset.clientKey = clientSdkKey;
#                 s.dataset.apiHost = apiHost;
#                 if (isStickyBucketingEnabled) {
#                     s.dataset.useStickyBucketService = 'localStorage';
#                     s.dataset.stickyBucketPrefix = 'gbStickyBuckets__';
#                 }
#                 s.dataset.uuid = userXid;
#                 s.dataset.enableDevMode = cnDebug.toString();
#                 s.src = `/verso/static/assets/growthbook.min.js`;
#                 document.head.appendChild(s);
#                 perfMark(`gb-script-start`);
#             }
#             else {
#                 console.warn('SDK loading skipped - missing requirements:', {
#                     hasClientSdkKey: !!clientSdkKey,
#                     hasApiHost: !!apiHost,
#                     enableClient,
#                     hasExpId: !!userXid
#                 });
#             }
#         }
#         catch (e) {
#             console.error('GrowthBook SDK loading error:', e);
#         }
#     })({"userAuthenticated":false,"section":"homepage","contentType":"homepage","hasBuyButtons":false,"clientSdkKey":"sdk-kq1g0bHkTprlhYB","apiHost":"https://variants.conde.digital","enableClient":true,"brandSlug":"epicurious"});</script></head><body class="stackednavigation-site-navigation fixed-header-logo-with-search-bar-nav-variation default"><noscript><iframe title="Google Tag Manager" src="https://www.googletagmanager.com/ns.html?id=GTM-PCTXLQR" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript><div id="app-root"><div><div class="BasePageWrapper-dnTkyh eAniYw page page-theme-standard standard HomepageWrapper-uACvA eBhQBx homepage standard"><div class="BasePageNavigationBackgroundFiller-hPBkdm CErOp"></div><div class="AdWrapper-efOWgS ddFpqJ BasePageAd-hoLrBf ciBtRv ad ad--out-of-page"><div class="ad__slot ad__slot--out-of-page" data-node-id="jvqwrk"></div></div><div class="AdWrapper-efOWgS ddFpqJ BasePageAd-hoLrBf ciBtRv ad ad--outstream"><div class="ad__slot ad__slot--outstream" data-node-id="vztfqz"></div></div><div class="AdWrapper-efOWgS ddFpqJ BasePageAd-hoLrBf ciBtRv ad ad--overlay"><div class="ad__slot ad__slot--overlay" data-node-id="lohqok"></div></div><a href="#main-content" data-testid="BasePageSkipLink" class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh BasePageSkipLink-PCnJP deqABF dVfXDd cLqibi kedKxB">Skip to main content</a><div class="InterstitialWrapper-bAlMkt jxJfiq"><aside class="PaywallModalWrapper-eXxAbG isXEiu paywall-modal paywall-modal--paywall"><div class="ConsumerMarketingUnitThemedWrapper-jkpAEW hssEkF ConsumerMarketingUnitWrapper-QIctH gUXkIE paywall-modal__consumer-marketing-unit consumer-marketing-unit consumer-marketing-unit--paywall-modal-full-barrier" role="presentation" aria-live="assertive" aria-hidden="true"><div class="consumer-marketing-unit__slot consumer-marketing-unit__slot--paywall-modal-full-barrier"></div><div class="journey-unit"></div></div></aside></div><div class="PersistentTopWrapper-ehBUAh kwCyfK persistent-top" data-testid="PersistentTop" data-journey-hook="persistent-top"><header data-testid="StackedNavigationHeader" class="StackedNavigationHeader-iQiNiy bgDyjd stacked-navigation--fixed-header-layout stacked-navigation--theme-standard site-navigation"><div class="ConsumerMarketingUnitThemedWrapper-jkpAEW hssEkF consumer-marketing-unit consumer-marketing-unit--cm-banner" role="presentation" aria-hidden="true"><div class="consumer-marketing-unit__slot consumer-marketing-unit__slot--cm-banner"></div><div class="journey-unit"></div></div><div class="StackedNavigationGrid-cqhnzl klDqoh"><div class="StackedNavigationTop-hoBqqC dtPGgL"><div class="StackedNavigationSectionCmUnitNavLeft-eGUBJi iAGSGE"><div class="ConsumerMarketingUnitThemedWrapper-jkpAEW hssEkF consumer-marketing-unit consumer-marketing-unit--nav-left" role="presentation" aria-hidden="true"><div class="consumer-marketing-unit__slot consumer-marketing-unit__slot--nav-left"></div><div class="journey-unit"></div></div></div><div class="StackedNavigationSectionLogoSize-fmhDSW gyqqDS stacked-navigation__section--xlarge-logo"><a href="/" data-testid="Logo" class="StackedNavigationLogoLink-bOjeJG jWIPUQ"><picture class="ResponsiveImagePicture-cGZhnX jwYQWO responsive-image"><img alt="Epicurious" class="ResponsiveImageContainer-eNxvmU cfBbTk responsive-image__image" srcSet="" sizes="100vw" src="/verso/static/epicurious-us/assets/logo.svg"/></picture></a></div><div class="StackedNavigationSectionUtilityLinks-krqoPz fkvSjV"><nav aria-label="Utility" class="NavigationWrapper-bKyjHN cUZDkX" data-testid="navigation"><ul class="NavigationListWrapper-hcqCdn dHmFGe navigation__list" data-testid="navigation__list"><li class="NavigationListItemWrapper-cNhNwu khKlxe navigation__list-item" data-testid="navigation__list-item"><a role="link" class="NavigationInternalLink-dbWQlJ cNvrNX navigation__link" href="/newsletter" data-testid="navigation__internal-link">Newsletter</a></li></ul></nav><span  ...

# %% [markdown]
# ###### [Back to top](#Index:)
#
# ### Question 2: Parse HTML Using BeautifulSoup
#
# Now that you have the raw HTML content, it's time to parse it using **BeautifulSoup**.
#
# #### Instructions
#
# 1. Use the `BeautifulSoup` class from the `bs4` library to parse the HTML stored in `ans1`.
# 2. Create a BeautifulSoup object and assign it to a variable named `soup`.
# 3. Use the `.prettify()` method to print the parsed HTML in a readable format.
#
# > This helps confirm that the structure of the parsed HTML matches what you see in your browser when inspecting the page.
#
# ---
#
# **Expected Behavior**
# - The variable `soup` should contain a valid `BeautifulSoup` object.
# - The output of `print(soup.prettify()[:1000000])` should closely resemble the HTML source of the page.
#
# > **Autograder Check**
# > The autograder will validate that:
# > - `soup` is a `BeautifulSoup` object initialized with the content of `ans1`.

# %%
from bs4 import BeautifulSoup

soup = None
soup = BeautifulSoup(ans1)

# Answer test
print(soup.prettify()[:1000000])
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <title>
#    Epicurious – Recipes, Menu Ideas, Videos &amp; Cooking Tips | Epicurious
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="no" name="msapplication-tap-highlight"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Condé Nast" name="author"/>
#   <meta content="Copyright (c) Condé Nast 2025" name="copyright"/>
#   <meta content="Since 1995, Epicurious has been the ultimate food resource for the home cook, with daily kitchen tips, fun cooking videos, and, oh yeah, over 33,000 recipes." name="description"/>
#   <meta content="6572b7bfdb20f77e6352a50e" name="id"/>
#   <meta content="" name="keywords"/>
#   <meta content="" name="news_keywords"/>
#   <meta content="index, follow, max-image-preview:large" name="robots"/>
#   <meta content="fbW4-SR7g-pDem3jW4eRKl9571SIF3cQiufsQDaxPds" name="google-site-verification"/>
#   <meta content="homepage" name="content-type"/>
#   <meta content="6572b7bfdb20f77e6352a50e" name="parsely-post-id"/>
#   <meta content='{"description":"Since 1995, Epicurious has been the ultimate food resource for the home cook, with daily kitchen tips, fun cooking videos, and, oh yeah, over 33,000 recipes.","image-16-9":"https://assets.epicurious.com/photos/656f72061ce0aa7243171bbd/16:9/w_1000,c_limit/Champagne-Cocktail_RECIPE_V1.jpg","image-1-1":"https://assets.epicurious.com/photos/656f72061ce0aa7243171bbd/1:1/w_1000,c_limit/Champagne-Cocktail_RECIPE_V1.jpg"}' name="parsely-metadata"/>
#   <meta content="Since 1995, Epicurious has been the ultimate food resource for the home cook, with daily kitchen tips, fun cooking videos, and, oh yeah, over 33,000 recipes." property="og:description"/>
#   <meta content="https://assets.epicurious.com/photos/656f72061ce0aa7243171bbd/16:9/w_1280,c_limit/Champagne-Cocktail_RECIPE_V1.jpg" property="og:image"/>
#   <meta content="Epicurious" property="og:site_name"/>
#   <meta content="Epicurious – Recipes, Menu Ideas, Videos &amp; Cooking Tips" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.epicurious.com/" property="og:url"/>
#   <meta content="free" property="article:content_tier"/>
#   <meta content="en-US" http-equiv="content-language"/>
#   <meta content="Condé Nast" property="article:author"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="@epicurious" property="twitter:creator"/>
#   <meta content="Since 1995, Epicurious has been the ultimate food resource for the home cook, with daily kitchen tips, fun cooking videos, and, oh yeah, over 33,000 recipes." property="twitter:description"/>
#   <meta content="https://www.epicurious.com" property="twitter:domain"/>
#   <meta content="https://assets.epicurious.com/photos/656f72061ce0aa7243171bbd/16:9/w_1280,c_limit/Champagne-Cocktail_RECIPE_V1.jpg?mbid=social_retweet" property="twitter:image"/>
#   <meta content="@epicurious" property="twitter:site"/>
#   <meta content="Epicurious – Recipes, Menu Ideas, Videos &amp; Cooking Tips" property="twitter:title"/>
#   <meta content="https://assets.epicurious.com/photos/656f72061ce0aa7243171bbd/2:3/w_1000,h_1500,c_limit/Champagne-Cocktail_RECIPE_V1.jpg" property="pinterest:image"/>
#   <meta content="2309869772" property="fb:app_id"/>
#   <meta content="12770210203" property="fb:pages"/>
#   <meta content="nopagereadaloud" name="google"/>
#   <script id="kendra" type="text/javascript">
#    (()=>{var r=class{constructor(){this.registry={}}register(t,e){if(this.registry[t])throw new Error("Event with key "+t+" already exists.");this.registry[t]=e,Object.defineProperty(this,t,{get(){return this.registry[t]},enumerable:!0,configurable:!1})}delete(t){delete this.registry[t],delete this[t]}get(t){let e=this.registry[t];if(!e)throw new Error("Event with key "+t+" is not registered.");return e}};(function(){let n=new r;window.Kendra=n})();})();
#   </script>
#   <link href="https://www.epicurious.com/" rel="canonical"/>
#   <link href="https://www.epicurious.com/feed/rss" rel="alternate" type="application/rss+xml"/>
#   <style data-styled="" data-styled-version="5.3.11">
#    .deqABF{margin:0;}/*!sc*/
# .cbdLXO{margin:0;text-align:center;}/*!sc*/
# .ftUkBG{margin:0;text-align:left;}/*!sc*/
# .ggJISK{margin:0;margin-bottom:3.5rem;}/*!sc*/
# data-styled.g1[id="BaseWrap-sc-gzmcOU"]{content:"deqABF,cbdLXO,ftUkBG,ggJISK,"}/*!sc*/
# .dVfXDd{--type-token:consumptionEditorial.body-core;text-transform:none;font-family:STIXTwoText ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.00588235302883036em;-moz-letter-spacing:0.00588235302883036em;-ms-letter-spacing:0.00588235302883036em;letter-spacing:0.00588235302883036em;line-break:auto;line-height:1.69em;font-size:17px;font-weight:400;overflow-wrap:normal;color:rgba(201,201,201,1);}/*!sc*/
# .dVfXDd a{color:inherit;}/*!sc*/
# .ijWuNu{--type-token:consumptionEditorial.body-core;text-transform:none;font-family:STIXTwoText ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.00588235302883036em;-moz-letter-spacing:0.00588235302883036em;-ms-letter-spacing:0.00588235302883036em;letter-spacing:0.00588235302883036em;line-break:auto;line-height:1.69em;font-size:17px;font-weight:400;overflow-wrap:normal;color:rgba(51,51,51,1);}/*!sc*/
# .ijWuNu a{color:inherit;}/*!sc*/
# .kjcnEi{--type-token:discovery.subhed-section-primary;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.09615384615384616em;-moz-letter-spacing:0.09615384615384616em;-ms-letter-spacing:0.09615384615384616em;letter-spacing:0.09615384615384616em;line-break:auto;line-height:1.229999982393705em;font-size:26px;font-weight:500;overflow-wrap:normal;color:rgba(51,51,51,1);}/*!sc*/
# @media (min-width:768px){.kjcnEi{font-size:24px;line-height:1.0833333333333333em;}}/*!sc*/
# .kjcnEi a{color:inherit;}/*!sc*/
# .gNRPUh{--type-token:discovery.hed-core-secondary;text-transform:none;font-family:SourceSerif ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.4099999596090877em;font-size:17px;font-weight:700;overflow-wrap:normal;color:rgba(51,51,51,1);}/*!sc*/
# @media (min-width:768px){.gNRPUh{font-size:20.399999618530273px;line-height:1.4098039591509492em;}}/*!sc*/
# .gNRPUh a{color:inherit;}/*!sc*/
# .hdGJiy{--type-token:discovery.description-core;text-transform:none;font-family:STIXTwoText ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.4699999491373699em;font-size:15px;font-weight:400;overflow-wrap:normal;color:rgba(80,80,80,1);}/*!sc*/
# .hdGJiy a{color:inherit;}/*!sc*/
# .fmWmyQ{--type-token:globalEditorial.numerical-large;text-transform:none;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.1699999968210857em;font-size:24px;font-weight:700;overflow-wrap:normal;color:rgba(80,80,80,1);}/*!sc*/
# .fmWmyQ a{color:inherit;}/*!sc*/
# .fINpWU{--type-token:globalEditorial.context-primary;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:500;overflow-wrap:normal;color:rgba(117,117,117,1);}/*!sc*/
# .fINpWU a{color:inherit;}/*!sc*/
# data-styled.g2[id="BaseText-eqOrNE"]{content:"dVfXDd,ijWuNu,kjcnEi,gNRPUh,hdGJiy,fmWmyQ,fINpWU,"}/*!sc*/
# .cLqibi{color:rgba(201,201,201,1);-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:5s;transition-duration:5s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;color:rgba(51,51,51,1);cursor:pointer;-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;}/*!sc*/
# .cLqibi:link{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(51,51,51,1);}/*!sc*/
# .cLqibi:visited{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(51,51,51,1);}/*!sc*/
# .cLqibi:hover{color:rgba(51,51,51,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .cLqibi:active{color:rgba(51,51,51,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .cLqibi:focus{color:rgba(51,51,51,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hsENAC{color:rgba(201,201,201,1);-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:5s;transition-duration:5s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;--type-token:foundation.link-primary;text-transform:none;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.07099999984105428em;-moz-letter-spacing:0.07099999984105428em;-ms-letter-spacing:0.07099999984105428em;letter-spacing:0.07099999984105428em;line-break:auto;line-height:1.4200000762939453em;font-size:14px;font-weight:500;overflow-wrap:normal;color:rgba(51,51,51,1);cursor:pointer;-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;}/*!sc*/
# .hsENAC:link{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(51,51,51,1);}/*!sc*/
# .hsENAC:visited{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(51,51,51,1);}/*!sc*/
# .hsENAC:hover{color:rgba(235,0,0,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hsENAC:active{color:rgba(235,0,0,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hsENAC:focus{color:rgba(235,0,0,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .fkcGxl{color:rgba(51,51,51,1);-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:5s;transition-duration:5s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;color:rgba(51,51,51,1);cursor:pointer;-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;}/*!sc*/
# .fkcGxl:link{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(51,51,51,1);}/*!sc*/
# .fkcGxl:visited{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(51,51,51,1);}/*!sc*/
# .fkcGxl:hover{color:rgba(51,51,51,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .fkcGxl:active{color:rgba(51,51,51,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .fkcGxl:focus{color:rgba(51,51,51,1);-webkit-text-decoration:undefined;text-decoration:undefined;}/*!sc*/
# data-styled.g3[id="BaseLink-eTpkqh"]{content:"cLqibi,hsENAC,fkcGxl,"}/*!sc*/
# .frFMjA{display:inline-block;background-color:rgba(201,201,201,1);cursor:pointer;text-align:center;-webkit-text-decoration:none;text-decoration:none;-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# .frFMjA:disabled{pointer-events:none;}/*!sc*/
# .frFMjA:hover,.frFMjA:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g4[id="BaseButton-lbLhfD"]{content:"frFMjA,"}/*!sc*/
# .jDxUnC{border:1px solid rgba(51,51,51,1);padding:0.125em 0.5rem;}/*!sc*/
# .jDxUnC[disabled]{pointer-events:none;}/*!sc*/
# .jDxUnC[type='checkbox']{position:absolute;top:0;right:0;bottom:0;left:0;visibility:initial;opacity:0;margin:0;cursor:inherit;padding:0;width:100%;height:100%;}/*!sc*/
# .jDxUnC[type='radio']{position:absolute;top:0;right:0;bottom:0;left:0;visibility:initial;opacity:0;margin:0;cursor:inherit;padding:0;width:100%;height:100%;}/*!sc*/
# .jDxUnC[type='submit']{display:inline-block;background-color:rgba(201,201,201,1);cursor:pointer;text-align:center;-webkit-text-decoration:none;text-decoration:none;-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# .jDxUnC[type='submit']:disabled{pointer-events:none;}/*!sc*/
# .jDxUnC[type='submit']:hover,.jDxUnC[type='submit']:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .jDxUnC[type='reset']{cursor:pointer;}/*!sc*/
# .jDxUnC[type='number']::-webkit-inner-spin-button{height:auto;}/*!sc*/
# .jDxUnC[type='number']::-webkit-outer-spin-button{height:auto;}/*!sc*/
# .jDxUnC[type='search']{box-sizing:border-box;}/*!sc*/
# data-styled.g5[id="BaseInput-fFSJlf"]{content:"jDxUnC,"}/*!sc*/
# .fWZsjA{display:block;width:100%;}/*!sc*/
# data-styled.g11[id="RowWrapper-EQDhp"]{content:"fWZsjA,"}/*!sc*/
# .ipyZZT{width:100%;}/*!sc*/
# .ipyZZT .icon-close{padding:8px;}/*!sc*/
# .ipyZZT .cns-ads-slot-state-filled.cns-ads-slot-type-hero{padding:8px 0;}/*!sc*/
# data-styled.g12[id="StickyHeroAdWrapper-eTeAbx"]{content:"ipyZZT,"}/*!sc*/
# .ddFpqJ.ddFpqJ.ad.should-hold-space{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;min-height:66px;}/*!sc*/
# @media (min-width:768px){.ddFpqJ.ddFpqJ.ad.should-hold-space{min-height:106px;}}/*!sc*/
# data-styled.g14[id="AdWrapper-efOWgS"]{content:"ddFpqJ,"}/*!sc*/
# .bpsHTm{padding-top:var(--header-height,56px);}/*!sc*/
# data-styled.g15[id="AdsSpacer-fqJTPo"]{content:"bpsHTm,"}/*!sc*/
# @media (max-width:768px){.jjLMxv{min-height:calc( ( 100px - 50px - 16px ) / 2 );}}/*!sc*/
# data-styled.g16[id="SpaceHolder-lkqTPQ"]{content:"jjLMxv,"}/*!sc*/
# .jlFMVt{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;z-index:1;border-radius:0px;padding:1rem;min-width:auto;height:auto;min-height:auto;-webkit-transition-property:color,background,border;transition-property:color,background,border;-webkit-transition-duration:200ms;transition-duration:200ms;-webkit-transition-timing-function:ease-in;transition-timing-function:ease-in;color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);--type-token:utility.button-utility;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;}/*!sc*/
# .jlFMVt .spinner{-webkit-transform:scale(1.125);-ms-transform:scale(1.125);transform:scale(1.125);-webkit-animation-name:spin;animation-name:spin;-webkit-animation-duration:1200ms;animation-duration:1200ms;-webkit-animation-timing-function:linear;animation-timing-function:linear;-webkit-animation-iteration-count:infinite;animation-iteration-count:infinite;}/*!sc*/
# .jlFMVt .spinner path{fill:black;}/*!sc*/
# @-webkit-keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}to{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# @keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}to{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# .jlFMVt.button--utility + .ButtonWrapper-igqDZ.button--utility{margin-top:1rem;}/*!sc*/
# .jlFMVt.button__icon--chevron-down .button-icon{-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# .jlFMVt.button__icon--chevron-up .button-icon{-webkit-transform:rotate(270deg);-ms-transform:rotate(270deg);transform:rotate(270deg);}/*!sc*/
# @media (min-width:768px){.jlFMVt{min-width:auto;}}/*!sc*/
# .jlFMVt:hover{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jlFMVt:focus{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jlFMVt:focus-visible{outline:3px solid #0066cc;outline-offset:3px;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jlFMVt:active{outline:none;}/*!sc*/
# .jlFMVt:active.ButtonWrapper-igqDZ:active{border-color:rgba(0,0,0,0.2);}/*!sc*/
# .jlFMVt:active::before{position:absolute;z-index:-1;width:100%;height:100%;content:'';}/*!sc*/
# .jlFMVt:active{outline:none;}/*!sc*/
# .jlFMVt:hover{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .jlFMVt:focus{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .jlFMVt:active{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .jlFMVt:disabled,.jlFMVt[aria-disabled='true'],.jlFMVt.jlFMVt[aria-disabled='true']:focus,.jlFMVt.jlFMVt[aria-disabled='true']:active{cursor:default;pointer-events:none;color:rgba(255,255,255,1);border-color:rgba(201,201,201,1);border-width:2px;border-style:solid;background-color:rgba(201,201,201,1);}/*!sc*/
# .dRemWM{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;z-index:1;border-radius:0px;padding:1rem;min-width:auto;height:auto;min-height:auto;-webkit-transition-property:color,background,border;transition-property:color,background,border;-webkit-transition-duration:200ms;transition-duration:200ms;-webkit-transition-timing-function:ease-in;transition-timing-function:ease-in;color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);--type-token:utility.button-core;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;}/*!sc*/
# .dRemWM .spinner{-webkit-transform:scale(1.125);-ms-transform:scale(1.125);transform:scale(1.125);-webkit-animation-name:spin;animation-name:spin;-webkit-animation-duration:1200ms;animation-duration:1200ms;-webkit-animation-timing-function:linear;animation-timing-function:linear;-webkit-animation-iteration-count:infinite;animation-iteration-count:infinite;}/*!sc*/
# .dRemWM .spinner path{fill:black;}/*!sc*/
# @-webkit-keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}to{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# @keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}to{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# .dRemWM.button--utility + .ButtonWrapper-igqDZ.button--utility{margin-top:1rem;}/*!sc*/
# .dRemWM.button__icon--chevron-down .button-icon{-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# .dRemWM.button__icon--chevron-up .button-icon{-webkit-transform:rotate(270deg);-ms-transform:rotate(270deg);transform:rotate(270deg);}/*!sc*/
# @media (min-width:768px){.dRemWM{min-width:auto;}}/*!sc*/
# .dRemWM:hover{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dRemWM:focus{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dRemWM:focus-visible{outline:3px solid #0066cc;outline-offset:3px;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dRemWM:active{outline:none;}/*!sc*/
# .dRemWM:active.ButtonWrapper-igqDZ:active{border-color:rgba(255,255,255,0.2);}/*!sc*/
# .dRemWM:active::before{position:absolute;z-index:-1;width:100%;height:100%;content:'';}/*!sc*/
# .dRemWM:active{outline:none;}/*!sc*/
# .dRemWM:hover{color:rgba(255,255,255,1);border-color:rgba(192,57,57,1);border-width:2px;border-style:solid;background-color:rgba(192,57,57,1);}/*!sc*/
# .dRemWM:focus{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .dRemWM:active{color:rgba(255,255,255,1);border-color:rgba(192,57,57,1);border-width:2px;border-style:solid;background-color:rgba(192,57,57,1);}/*!sc*/
# .dRemWM:disabled,.dRemWM[aria-disabled='true'],.dRemWM.dRemWM[aria-disabled='true']:focus,.dRemWM.dRemWM[aria-disabled='true']:active{cursor:default;pointer-events:none;color:rgba(255,255,255,1);border-color:rgba(201,201,201,1);border-width:2px;border-style:solid;background-color:rgba(201,201,201,1);}/*!sc*/
# .kQBHiR{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;position:relative;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;z-index:1;border-radius:0px;padding:1rem;min-width:auto;height:auto;min-height:auto;-webkit-transition-property:color,background,border;transition-property:color,background,border;-webkit-transition-duration:200ms;transition-duration:200ms;-webkit-transition-timing-function:ease-in;transition-timing-function:ease-in;color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);--type-token:utility.button-utility;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;}/*!sc*/
# .kQBHiR .spinner{-webkit-transform:scale(1.125);-ms-transform:scale(1.125);transform:scale(1.125);-webkit-animation-name:spin;animation-name:spin;-webkit-animation-duration:1200ms;animation-duration:1200ms;-webkit-animation-timing-function:linear;animation-timing-function:linear;-webkit-animation-iteration-count:infinite;animation-iteration-count:infinite;}/*!sc*/
# .kQBHiR .spinner path{fill:black;}/*!sc*/
# @-webkit-keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}to{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# @keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}to{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# .kQBHiR.button--utility + .ButtonWrapper-igqDZ.button--utility{margin-top:1rem;}/*!sc*/
# .kQBHiR.button__icon--chevron-down .button-icon{-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# .kQBHiR.button__icon--chevron-up .button-icon{-webkit-transform:rotate(270deg);-ms-transform:rotate(270deg);transform:rotate(270deg);}/*!sc*/
# @media (min-width:768px){.kQBHiR{min-width:auto;}}/*!sc*/
# .kQBHiR:hover{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .kQBHiR:focus{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .kQBHiR:focus-visible{outline:3px solid #0066cc;outline-offset:3px;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .kQBHiR:active{outline:none;}/*!sc*/
# .kQBHiR:active.ButtonWrapper-igqDZ:active{border-color:rgba(0,0,0,0.2);}/*!sc*/
# .kQBHiR:active::before{position:absolute;z-index:-1;width:100%;height:100%;content:'';}/*!sc*/
# .kQBHiR:active{outline:none;}/*!sc*/
# .kQBHiR:hover{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .kQBHiR:focus{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .kQBHiR:active{color:rgba(255,255,255,1);border-color:rgba(51,51,51,1);border-width:2px;border-style:solid;background-color:rgba(51,51,51,1);}/*!sc*/
# .kQBHiR:disabled,.kQBHiR[aria-disabled='true'],.kQBHiR.kQBHiR[aria-disabled='true']:focus,.kQBHiR.kQBHiR[aria-disabled='true']:active{cursor:default;pointer-events:none;color:rgba(255,255,255,1);border-color:rgba(201,201,201,1);border-width:2px;border-style:solid;background-color:rgba(201,201,201,1);}/*!sc*/
# data-styled.g17[id="ButtonWrapper-igqDZ"]{content:"jlFMVt,dRemWM,kQBHiR,"}/*!sc*/
# .hvohFn{font-variant-ligatures:none;padding:0.5rem 0;position:absolute;margin:0;border:0;padding:0;width:1px;height:1px;overflow:hidden;-webkit-clip:rect(0 0 0 0);clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);white-space:nowrap;}/*!sc*/
# data-styled.g18[id="ButtonLabel-cyWivE"]{content:"hvohFn,"}/*!sc*/
# .bQqPLN{padding-right:0;padding-left:0;}/*!sc*/
# data-styled.g19[id="ButtonIconWrapper-gzKJtq"]{content:"bQqPLN,"}/*!sc*/
# .jKYSoZ{display:block;width:32px;height:32px;}/*!sc*/
# data-styled.g21[id="ButtonIcon-bdIQNJ"]{content:"jKYSoZ,"}/*!sc*/
# .jUhiFc.jUhiFc{--grid-gap:1rem;--grid-margin:1.5rem;gap:var(--grid-gap);padding-right:calc(1 * var(--grid-margin));padding-left:calc(1 * var(--grid-margin));margin:0 auto;width:100%;max-width:1600px;}/*!sc*/
# @media (min-width:768px){.jUhiFc.jUhiFc{--grid-gap:1.5rem;--grid-margin:3rem;}}/*!sc*/
# @media (min-width:1024px){.jUhiFc.jUhiFc{--grid-gap:2rem;}}/*!sc*/
# @media (min-width:1280px){.jUhiFc.jUhiFc{--grid-margin:4rem;}}/*!sc*/
# .jUhiFc.jUhiFc .newsletter-plp-full-bleed{display:grid;grid-column:1/-1;}/*!sc*/
# @media (max-width:1024px){}/*!sc*/
# @media (min-width:768px){.jUhiFc.jUhiFc{grid-template-columns:repeat(12,1fr);}}/*!sc*/
# .jUhiFc.jUhiFc.jUhiFc.jUhiFc{display:block;grid-template-columns:unset;}/*!sc*/
# .fubVbh.fubVbh{--grid-gap:1rem;--grid-margin:1.5rem;display:grid;grid-template-columns:repeat(4,1fr);gap:var(--grid-gap);padding-right:calc(1 * var(--grid-margin));padding-left:calc(1 * var(--grid-margin));margin:0 auto;width:100%;max-width:1600px;}/*!sc*/
# @media (min-width:768px){.fubVbh.fubVbh{--grid-gap:1.5rem;--grid-margin:3rem;}}/*!sc*/
# @media (min-width:1024px){.fubVbh.fubVbh{--grid-gap:2rem;}}/*!sc*/
# @media (min-width:1280px){.fubVbh.fubVbh{--grid-margin:4rem;}}/*!sc*/
# .fubVbh.fubVbh .newsletter-plp-full-bleed{display:grid;grid-column:1/-1;}/*!sc*/
# @media (max-width:1024px){}/*!sc*/
# @media (min-width:768px){.fubVbh.fubVbh{grid-template-columns:repeat(12,1fr);}}/*!sc*/
# .bSEvzF.bSEvzF{--grid-gap:1rem;--grid-margin:1.5rem;display:grid;grid-template-columns:repeat(4,1fr);gap:var(--grid-gap);padding-right:calc(1 * var(--grid-margin));padding-left:calc(1 * var(--grid-margin));margin:0 auto;width:100%;max-width:1600px;}/*!sc*/
# @media (min-width:768px){.bSEvzF.bSEvzF{--grid-gap:1.5rem;--grid-margin:3rem;}}/*!sc*/
# @media (min-width:1024px){.bSEvzF.bSEvzF{--grid-gap:2rem;}}/*!sc*/
# @media (min-width:1280px){.bSEvzF.bSEvzF{--grid-margin:4rem;}}/*!sc*/
# .bSEvzF.bSEvzF .newsletter-plp-full-bleed{display:grid;grid-column:1/-1;}/*!sc*/
# @media (max-width:1024px){}/*!sc*/
# @media (min-width:768px){.bSEvzF.bSEvzF{grid-template-columns:repeat(12,1fr);}}/*!sc*/
# @media (min-width:1024px) and (max-width:1045px){.bSEvzF.bSEvzF{grid-template-columns:repeat(8,1fr) minmax(300px,4fr);}}/*!sc*/
# @media (min-width:1280px) and (max-width:1393px){.bSEvzF.bSEvzF{grid-template-columns:repeat(9,1fr) minmax(300px,3fr);}}/*!sc*/
# .crAyIs.crAyIs{--grid-gap:1rem;--grid-margin:1.5rem;display:grid;grid-template-columns:repeat(4,1fr);gap:var(--grid-gap);margin:0 auto;width:100%;max-width:1600px;}/*!sc*/
# @media (min-width:768px){.crAyIs.crAyIs{--grid-gap:1.5rem;--grid-margin:3rem;}}/*!sc*/
# @media (min-width:1024px){.crAyIs.crAyIs{--grid-gap:2rem;}}/*!sc*/
# @media (min-width:1280px){.crAyIs.crAyIs{--grid-margin:4rem;}}/*!sc*/
# .crAyIs.crAyIs .newsletter-plp-full-bleed{display:grid;grid-column:1/-1;}/*!sc*/
# @media (max-width:1024px){}/*!sc*/
# @media (min-width:768px){.crAyIs.crAyIs{grid-template-columns:repeat(12,1fr);}}/*!sc*/
# data-styled.g25[id="GridWrapper-cFSKbf"]{content:"jUhiFc,fubVbh,bSEvzF,crAyIs,"}/*!sc*/
# .iEWjAa{grid-column:1 / -1;}/*!sc*/
# @media (min-width:1024px){.iEWjAa{grid-column:span 8;}}/*!sc*/
# @media (min-width:1280px){.iEWjAa{grid-column:span 9;}}/*!sc*/
# .cNAFhG{display:none;}/*!sc*/
# @media (min-width:1024px){.cNAFhG{display:block;justify-self:start;}}/*!sc*/
# @media (min-width:1280px){.cNAFhG{display:block;}.cNAFhG .ad--rail{max-width:300px;}}/*!sc*/
# @media (min-width:1024px){.cNAFhG{grid-column:9 / -1;}}/*!sc*/
# @media (min-width:1280px){.cNAFhG{grid-column:10 / -1;}}/*!sc*/
# .dORtPa{grid-column:1/-1;}/*!sc*/
# @media (min-width:768px){.dORtPa{grid-column:span 6;}}/*!sc*/
# data-styled.g26[id="GridItem-beYvyV"]{content:"bRelOV,iEWjAa,cNAFhG,dORtPa,"}/*!sc*/
# .gkOnUH{--type-token:utility.input-core;text-transform:none;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.25em;font-size:16px;font-weight:400;overflow-wrap:normal;margin-top:0.5rem;padding:0.5rem 0.75rem;width:100%;text-transform:none;-webkit-transition-property:color,background,border;transition-property:color,background,border;-webkit-transition-duration:200ms;transition-duration:200ms;-webkit-transition-timing-function:ease-in;transition-timing-function:ease-in;background-color:rgba(255,255,255,1);color:rgba(117,117,117,1);border-width:1px;border-style:solid;border-color:rgba(201,201,201,1);border-radius:0;height:3rem;-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# .gkOnUH:focus{outline:0;}/*!sc*/
# .gkOnUH:focus + .TextFieldIcon-fQIYjY svg{fill:rgba(51,51,51,1);}/*!sc*/
# .gkOnUH:active,.gkOnUH:focus{background-color:rgba(255,255,255,1);color:rgba(51,51,51,1);border-width:1px;border-style:solid;border-color:rgba(51,51,51,1);}/*!sc*/
# .gkOnUH[disabled]{background-color:rgba(201,201,201,1);color:rgba(117,117,117,1);border-width:1px;border-style:solid;border-color:rgba(117,117,117,1);}/*!sc*/
# data-styled.g32[id="TextFieldControlInput-eABHcK"]{content:"gkOnUH,"}/*!sc*/
# .ckirip .TextFieldIcon-fQIYjY svg{fill:rgba(117,117,117,1);pointer-events:none;}/*!sc*/
# data-styled.g35[id="TextFieldLabel-jVWkJp"]{content:"ckirip,"}/*!sc*/
# .diAzpa{position:relative;grid-column:1;}/*!sc*/
# .diAzpa input[type='search']{-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# data-styled.g36[id="TextFieldInputContainer-iXtYZG"]{content:"diAzpa,"}/*!sc*/
# .cNiSue{display:grid;margin-bottom:1rem;}/*!sc*/
# @media (min-width:768px){}/*!sc*/
# .cNiSue::-webkit-input-placeholder{--color__token-name:colors.interactive.base.dark;color:rgba(117,117,117,1);}/*!sc*/
# .cNiSue::-moz-placeholder{--color__token-name:colors.interactive.base.dark;color:rgba(117,117,117,1);}/*!sc*/
# .cNiSue:-ms-input-placeholder{--color__token-name:colors.interactive.base.dark;color:rgba(117,117,117,1);}/*!sc*/
# .cNiSue::placeholder{--color__token-name:colors.interactive.base.dark;color:rgba(117,117,117,1);}/*!sc*/
# data-styled.g41[id="TextFieldWrapper-KgniU"]{content:"cNiSue,"}/*!sc*/
# .eHOOfj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:100%;height:100%;}/*!sc*/
# .eHOOfj .icon{width:100%;height:100%;}/*!sc*/
# .eHOOfj .icon-shopping{width:initial;height:initial;}/*!sc*/
# data-styled.g56[id="SocialIconViewBox-eHrlQI"]{content:"eHOOfj,"}/*!sc*/
# .fuiLqy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:32px;width:32px;}/*!sc*/
# .fuiLqy.fuiLqy.fuiLqy.fuiLqy .icon{-webkit-transform:none;-ms-transform:none;transform:none;width:100%;height:100%;}/*!sc*/
# data-styled.g57[id="SocialIconContainer-hAqqbX"]{content:"fuiLqy,"}/*!sc*/
# .achyN{-webkit-text-decoration:none;text-decoration:none;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:3rem;height:3rem;}/*!sc*/
# .achyN:hover,.achyN:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .achyN path{--fill__token-name:colors.foundation.footer.links.primary;fill:rgba(255,255,255,1);}/*!sc*/
# .achyN:hover path{--fill__token-name:colors.foundation.footer.social.hover;fill:rgba(226,221,204,1);}/*!sc*/
# data-styled.g58[id="SocialIconExternalLink-hzNpWp"]{content:"achyN,"}/*!sc*/
# .iCoXyS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;gap:1rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:0;margin-bottom:0;margin-left:-1rem;padding-left:0;list-style:none;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-left:0rem;}/*!sc*/
# @media (min-width:1024px){.iCoXyS{-webkit-box-pack:start;-webkit-justify-content:start;-ms-flex-pack:start;justify-content:start;}}/*!sc*/
# data-styled.g60[id="SocialIconsList-cNoJPV"]{content:"iCoXyS,"}/*!sc*/
# .gmnjub{false;}/*!sc*/
# @media (min-width:320px){.gmnjub{-webkit-box-pack:start;-webkit-justify-content:start;-ms-flex-pack:start;justify-content:start;}}/*!sc*/
# data-styled.g61[id="SocialIconsWrapper-iaisJM"]{content:"gmnjub,"}/*!sc*/
# .dugjwV .icon-bookmark path{-webkit-transition:all 0.2s ease-in-out;transition:all 0.2s ease-in-out;}/*!sc*/
# data-styled.g62[id="SocialIconNetworkIconComponent-dowysq"]{content:"dugjwV,"}/*!sc*/
# .gNSsSY{--type-token:utility.button-core;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:24px 0 32px 0;border-color:white;background:rgba(51,51,51,0.08);padding:17px 20px;--color__token-name:colors.interactive.base.black;color:rgba(51,51,51,1);-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:14px 16px;width:48px;margin:0px;}/*!sc*/
# .gNSsSY:hover{--type-token:utility.button-core;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;border-color:white;background:rgba(51,51,51,0.3);--color__token-name:colors.interactive.base.black;color:rgba(51,51,51,1);}/*!sc*/
# .gNSsSY:focus{--type-token:utility.button-core;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;border-color:white;background:rgba(51,51,51,0.3);--color__token-name:colors.interactive.base.black;color:rgba(51,51,51,1);}/*!sc*/
# .gNSsSY:active{--type-token:utility.button-core;text-transform:uppercase;font-family:Renner ,helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.08299999435742696em;-moz-letter-spacing:0.08299999435742696em;-ms-letter-spacing:0.08299999435742696em;letter-spacing:0.08299999435742696em;line-break:auto;line-height:1.4200000762939453em;font-size:12px;font-weight:700;overflow-wrap:normal;border-color:white;background:rgba(51,51,51,0.08);--color__token-name:colors.interactive.base.black;color:rgba(51,51,51,1);}/*!sc*/
# @media (min-width:768px){.gNSsSY{display:none;}}/*!sc*/
# data-styled.g63[id="SocialIconButton-dpYFeu"]{content:"gNSsSY,"}/*!sc*/
# .jwYQWO{display:inline-block;position:relative;width:-webkit-fill-available;width:-moz-available;width:fill-available;}/*!sc*/
# data-styled.g74[id="ResponsiveImagePicture-cGZhnX"]{content:"jwYQWO,"}/*!sc*/
# .koTknX{display:block;-webkit-transition:opacity 1s;transition:opacity 1s;opacity:1;overflow:hidden;}/*!sc*/
# data-styled.g110[id="SpanWrapper-zEXFr"]{content:"koTknX,"}/*!sc*/
# @media (max-width:767px){.ikOINK::before{content:'';display:block;padding-top:min(100%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# @media (min-width:768px){.ikOINK::before{content:'';display:block;padding-top:min(100%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# .ikOINK > .aspect-ratio--overlay-container{bottom:0;left:0;overflow:hidden;position:absolute;right:0;top:0;}/*!sc*/
# @media (max-width:767px){.eJpBwO::before{content:'';display:block;padding-top:min(66.66666666666666%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# @media (min-width:768px){.eJpBwO::before{content:'';display:block;padding-top:min(66.66666666666666%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# .eJpBwO > .aspect-ratio--overlay-container{bottom:0;left:0;overflow:hidden;position:absolute;right:0;top:0;}/*!sc*/
# @media (max-width:767px){.cErxRK::before{content:'';display:block;padding-top:min(56.25%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# @media (min-width:768px){.cErxRK::before{content:'';display:block;padding-top:min(56.25%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# .cErxRK > .aspect-ratio--overlay-container{bottom:0;left:0;overflow:hidden;position:absolute;right:0;top:0;}/*!sc*/
# @media (max-width:767px){.dKhhoi::before{content:'';display:block;padding-top:min(133.33333333333331%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# @media (min-width:768px){.dKhhoi::before{content:'';display:block;padding-top:min(133.33333333333331%,var(--aspect-ratio-box-max-height,200vh));width:100%;}}/*!sc*/
# .dKhhoi > .aspect-ratio--overlay-container{bottom:0;left:0;overflow:hidden;position:absolute;right:0;top:0;}/*!sc*/
# data-styled.g161[id="AspectRatioContainer-bEozCe"]{content:"ikOINK,eJpBwO,cErxRK,dKhhoi,"}/*!sc*/
# .ifVTHa{margin-left:0.5rem;}/*!sc*/
# data-styled.g182[id="RatingRatings-gXBeiH"]{content:"ifVTHa,"}/*!sc*/
# .fPHLgP.fPHLgP.fPHLgP{position:absolute;top:7px;left:7px;width:18px;height:18px;}/*!sc*/
# .fPHLgP.fPHLgP.fPHLgP path{--fill__token-name:colors.interactive.base.brand-primary;fill:rgba(51,51,51,1);}/*!sc*/
# .ihrDUu.ihrDUu.ihrDUu{position:absolute;top:7px;left:7px;width:18px;height:18px;}/*!sc*/
# .ihrDUu.ihrDUu.ihrDUu path{--fill__token-name:colors.interactive.base.brand-primary;fill:rgba(51,51,51,1);}/*!sc*/
# .ihrDUu.ihrDUu.ihrDUu.ihrDUu.ihrDUu.ihrDUu path:nth-of-type(1){--fill__token-name:colors.interactive.base.brand-primary;fill:rgba(51,51,51,1);}/*!sc*/
# data-styled.g183[id="RatingStarHalf-kKVCTE"]{content:"fPHLgP,ihrDUu,"}/*!sc*/
# .jofiAG{position:relative;width:32px;height:32px;}/*!sc*/
# data-styled.g184[id="RatingStar-bDVkyb"]{content:"jofiAG,"}/*!sc*/
# .iobXOd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# data-styled.g185[id="RatingStars-iURqAQ"]{content:"iobXOd,"}/*!sc*/
# .IfkO.IfkO.IfkO{all:unset;cursor:pointer;}/*!sc*/
# .IfkO.IfkO.IfkO::before{content:none;}/*!sc*/
# .IfkO.IfkO.IfkO::after{content:none;}/*!sc*/
# data-styled.g186[id="RatingLabel-cTXwMB"]{content:"IfkO,"}/*!sc*/
# .fzuyjx.fzuyjx.fzuyjx{all:unset;position:absolute;margin:0;border:0;padding:0;width:1px;height:1px;overflow:hidden;-webkit-clip:rect(0 0 0 0);clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);white-space:nowrap;}/*!sc*/
# .fzuyjx.fzuyjx.fzuyjx:disabled + .RatingLabel-cTXwMB{cursor:pointer;}/*!sc*/
# .fzuyjx.fzuyjx.fzuyjx:focus + .RatingLabel-cTXwMB{outline:#2360c5 auto 1px;}/*!sc*/
# .weCTb.weCTb.weCTb{all:unset;position:absolute;margin:0;border:0;padding:0;width:1px;height:1px;overflow:hidden;-webkit-clip:rect(0 0 0 0);clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);white-space:nowrap;}/*!sc*/
# .weCTb.weCTb.weCTb + .RatingLabel-cTXwMB ~ .RatingLabel-cTXwMB .RatingStarHalf-kKVCTE path{--fill__token-name:colors.interactive.base.light;fill:rgba(201,201,201,1);}/*!sc*/
# .weCTb.weCTb.weCTb:disabled + .RatingLabel-cTXwMB{cursor:pointer;}/*!sc*/
# .weCTb.weCTb.weCTb:focus + .RatingLabel-cTXwMB{outline:#2360c5 auto 1px;}/*!sc*/
# data-styled.g187[id="RatingInput-ccHABN"]{content:"fzuyjx,weCTb,"}/*!sc*/
# .fgPsvs{margin-right:0.5rem;}/*!sc*/
# data-styled.g189[id="RatingRating-bJravU"]{content:"fgPsvs,"}/*!sc*/
# .fBJMkW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g190[id="RatingFormWrapper-bmbFgi"]{content:"fBJMkW,"}/*!sc*/
# .hmNReC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:1.5rem 0 2rem;width:100%;}/*!sc*/
# data-styled.g191[id="RatingWrapper-bWyTJA"]{content:"hmNReC,"}/*!sc*/
# .dXwrHB{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;position:absolute;bottom:0.5rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-transition:background 200ms ease;transition:background 200ms ease;border:0;border-radius:50%;background:rgba( 255,255,255, 0.85 );padding:0;width:48px;height:48px;left:0.5rem;}/*!sc*/
# .dXwrHB .ButtonIconWrapper-gzKJtq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .dXwrHB .ButtonIconWrapper-gzKJtq .ButtonIcon-bdIQNJ{margin-left:2px;width:auto;height:auto;}/*!sc*/
# .dXwrHB .icon{--fill__token-name:colors.interactive.base.black;fill:rgba(51,51,51,1);}/*!sc*/
# .dXwrHB:hover,.dXwrHB:active,.dXwrHB:focus{border:0;background:rgba( 255,255,255, 0.85 );}/*!sc*/
# data-styled.g198[id="InlineVideoItemIconButton-kbRQes"]{content:"dXwrHB,"}/*!sc*/
# .jxeESw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;margin-top:0.5rem;}/*!sc*/
# .jxeESw .button__icon-container{margin-left:auto;cursor:pointer;}/*!sc*/
# .jxeESw .SocialIconButton-dpYFeu{display:contents;}/*!sc*/
# .jxeESw .SocialIconButton-dpYFeu .icon-bookmark{padding:3px;width:1.5rem;height:1.5rem;}/*!sc*/
# data-styled.g200[id="UtilityFeaturesWrapper-eNKivI"]{content:"jxeESw,"}/*!sc*/
# .ftRvdL{position:relative;}/*!sc*/
# data-styled.g203[id="ImageWrapper-chXNAU"]{content:"ftRvdL,"}/*!sc*/
# .deWMOT{border-radius:8px;padding:1rem 0.25rem 0.5rem;}/*!sc*/
# @media (min-width:768px){.deWMOT{border-radius:16px;padding:1.5rem 0.5rem 0.5rem;}}/*!sc*/
# @media (min-width:1024px){.deWMOT{border-radius:20px;}}/*!sc*/
# data-styled.g204[id="ContentWrapper-bCkkJm"]{content:"deWMOT,"}/*!sc*/
# .yjlRJ{padding:0 0 1rem;}/*!sc*/
# data-styled.g205[id="Content-ifkqHN"]{content:"yjlRJ,"}/*!sc*/
# .ffDePc{cursor:pointer;}/*!sc*/
# data-styled.g206[id="StackedRatingsCardWrapper-ghvskg"]{content:"ffDePc,"}/*!sc*/
# .bVFNUa img{border-radius:8px;width:-webkit-fill-available;width:-moz-available;width:fill-available;}/*!sc*/
# @media (min-width:768px){.bVFNUa img{border-radius:16px;width:-webkit-fill-available;width:-moz-available;width:fill-available;}}/*!sc*/
# @media (min-width:1024px){.bVFNUa img{border-radius:16px;width:-webkit-fill-available;width:-moz-available;width:fill-available;}}/*!sc*/
# data-styled.g208[id="Image-bQSkvr"]{content:"bVFNUa,"}/*!sc*/
# .hIjmI .SkeletonScreenWrapper-fXVbem{margin:0.5rem 0;}/*!sc*/
# data-styled.g210[id="Body-hsMkus"]{content:"hIjmI,"}/*!sc*/
# .fEQvtj{display:inline;margin:0 0 0.5rem;}/*!sc*/
# data-styled.g211[id="Hed-gQCsFV"]{content:"fEQvtj,"}/*!sc*/
# .iIPzBh{margin:0.5rem 0 0;}/*!sc*/
# data-styled.g212[id="Dek-eHIsq"]{content:"iIPzBh,"}/*!sc*/
# .eFPnQC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:2rem;display:block;}/*!sc*/
# .eFPnQC .SocialIconContainer-hAqqbX{height:1.1rem;}/*!sc*/
# .eFPnQC .SocialIconButton-dpYFeu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:auto;border:0;background:none;padding:0;width:1.25rem;list-style:none;}/*!sc*/
# .eFPnQC .SocialIconButton-dpYFeu .icon-bookmark.icon{height:1.25rem;}/*!sc*/
# .eFPnQC .SkeletonScreenWrapper-fXVbem{margin-right:0.125rem;}/*!sc*/
# .eFPnQC .SkeletonScreenWrapper-fXVbem:last-child{margin-left:auto;}/*!sc*/
# .fRIzEv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:2rem;}/*!sc*/
# .fRIzEv .SocialIconContainer-hAqqbX{height:1.1rem;}/*!sc*/
# .fRIzEv .SocialIconButton-dpYFeu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:auto;border:0;background:none;padding:0;width:1.25rem;list-style:none;}/*!sc*/
# .fRIzEv .SocialIconButton-dpYFeu .icon-bookmark.icon{height:1.25rem;}/*!sc*/
# ...
#                 <h3 class="SummaryItemHedBase-hnYOxl gezEsh summary-item__hed" data-testid="SummaryItemHed">
#                  HelloFresh's Crowd-Pleasing, Beginner-Friendly Recipes Don't Skimp on Flavor
#                 </h3>
#                </a>
#                <div class="BaseWrap-sc-gzmcOU BaseText-eqOrNE SummaryItemDek-IjVzD deqABF hdGJiy ktUePR summary-item__dek">
#                 Now we get why this is the most popular meal delivery service in the country.
#                </div>
#                <div class="UtilityFeaturesWrapper-eNKivI jxeESw" data-testid="utility-features-wrapper">
#                </div>
#               </div>
#              </div>
#              <div class="AdWrapper-efOWgS ddFpqJ SummaryCollectionGridSummaryItem-HgAzv iXQpLM ad ad--read-more">
#               <div class="ad__slot ad__slot--read-more" data-node-id="spsg78">
#               </div>
#              </div>
#             </div>
#             <div class="SummaryCollectionGridToActionWrapper-giyozs jYNcsH">
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="BaseWrap-sc-gzmcOU RowWrapper-EQDhp deqABF fWZsjA MultiPackageBaseRow-hhJkBI MultiPackageRow-cCQMGi gRCntk fyQfnD" data-journey-hook="row-content" data-testid="RowWrapper" id="fall-cooking">
#         <section class="SpotlightSummaryContainer-gtZcEh dDIaYG" data-testid="SpotlightSummaryContainer">
#          <div class="SpotlightSummaryInnerContainer-iLiKPn feWwWP">
#           <div class="SpotlightSummarySingleColumn-cJeWsm liaLlw">
#            <div class="SectionTitleRoot-dmkHrz eJiWgb SpotlightHeader-iHiwNF cEjFpj SpotlightSectionTitle" data-testid="SectionTitle">
#             <h2 class="BaseWrap-sc-gzmcOU BaseText-eqOrNE SectionTitleHed-dZMMQk cbdLXO kjcnEi cAtXuK">
#              Fall Cooking
#             </h2>
#             <div class="SectionTitleDivider-dRHzfM unBjX">
#             </div>
#            </div>
#            <section class="SpotlightSummaryGrid-bQowEO bIVDvv">
#             <div class="GridWrapper-cFSKbf crAyIs grid grid-items-2 SummarySpotlightGrid-QKUPS gPBRFW" data-journey-hook="grid-wrapper">
#              <div class="GridItem-beYvyV dORtPa grid--item">
#               <div class="SpotlightMainFeatureCover-jUgWrs kMrbVy">
#                <h3 class="SpotlightMainFeatureHeader-egCODZ eOpdvt" data-testid="SpotlightMainFeatureHeader">
#                 <a data-section-title="Author Spotlight/47 Fall Dinner Ideas You’ll Crave All Season 1" href="/recipes-menus/fall-dinner-ideas">
#                  47 Fall Dinner Ideas You’ll Crave All Season
#                 </a>
#                </h3>
#                <div class="SpotlightRatingWrapper-jGFDLm kKiWwN">
#                 <a class="SpotlightMainFeatureCoverImageWrapper-iOHdjo imIrYr" data-section-title="Author Spotlight/47 Fall Dinner Ideas You’ll Crave All Season 1-image" href="/recipes-menus/fall-dinner-ideas" tabindex="-1">
#                  <span class="SpanWrapper-zEXFr koTknX responsive-asset SpotlightMainFeatureCoverImage-NtlCb djbbKc">
#                   <picture class="ResponsiveImagePicture-cGZhnX jwYQWO SpotlightMainFeatureCoverImage-NtlCb djbbKc responsive-image">
#                    <source media="(max-width: 767px)" sizes="100vw" srcset="https://assets.epicurious.com/photos/68071449a3c6e73b67354d8d/3:4/w_120,c_limit/popover-topped-vegetarian-pot-pie_LEDE_V4_021325_1291_VOG_final.jpg 120w, https://assets.epicurious.com/photos/68071449a3c6e73b67354d8d/3:4/w_240,c_limit/popover-topped-vegetarian-pot-pie_LEDE_V4_021325_1291_VOG_final.jpg 240w, https://assets.epicurious.com/photos/68071449a3c6e73b67354d8d/3:4/w_320,c_limit/popover-topped-vegetarian-pot-pie_LEDE_V4_021325_1291_VOG_final.jpg 320w, https://assets.epicurious.com/photos/68071449a3c6e73b67354d8d/3:4/w_640,c_limit/popover-topped-vegetarian-pot-pie_LEDE_V4_021325_1291_VOG_final.jpg 640w"/>
#                    <source media="(min-width: 768px)" sizes="100vw" srcset="https://assets.epicurious.com/photos/68071449a3c6e73b67354d8d/3:4/w_120,c_limit/popover-topped-vegetarian-pot-pie_LEDE_V4_021325_1291_VOG_final.jpg 120w, https://assets.epicurious.com/photos/68071449a3c6e73b67354d8d/3:4/w_240,c_limit/popover-topped-vegetarian-pot-pie_LEDE_V4_021325_1291_VOG_final.jpg 240w, https://assets.epicurious.com/photos/68071449a3c6e73b67354d8d/3:4/w_320,c_limit/popover-topped-vegetarian-pot-pie_LEDE_V4_021325_1291_VOG_final.jpg 320w, https://assets.epicurious.com/photos/68071449a3c6e73b67354d8d/3:4/w_640,c_limit/popover-topped-vegetarian-pot-pie_LEDE_V4_021325_1291_VOG_final.jpg 640w, https://assets.epicurious.com/photos/68071449a3c6e73b67354d8d/3:4/w_960,c_limit/popover-topped-vegetarian-pot-pie_LEDE_V4_021325_1291_VOG_final.jpg 960w"/>
#                    <img alt="A popover topped pot pie with carrots peas green beans and asparagus in a stainless steel pan." class="ResponsiveImageContainer-eNxvmU cfBbTk responsive-image__image" data-src="https://assets.epicurious.com/photos/68071449a3c6e73b67354d8d/3:4/w_1024%2Cc_limit/popover-topped-vegetarian-pot-pie_LEDE_V4_021325_1291_VOG_final.jpg" loading="lazy" src="https://assets.epicurious.com/photos/68071449a3c6e73b67354d8d/3:4/w_1024%2Cc_limit/popover-topped-vegetarian-pot-pie_LEDE_V4_021325_1291_VOG_final.jpg"/>
#                   </picture>
#                  </span>
#                 </a>
#                </div>
#               </div>
#              </div>
#              <div class="GridItem-beYvyV dORtPa grid--item">
#               <div class="SpotlightMainFeatureContent-bVOEac ebznkP" data-testid="SpotlightMainFeatureContent">
#                Fall is here and with it comes cooler temperatures that beget cozy braises, roast chickens, spiced cocktails, and sweet treats to share with friends.
#               </div>
#               <section class="SelectedStoriesGrid-hidoTc fWiqav">
#                <div class="GridWrapper-cFSKbf jUhiFc grid grid-margins grid-margin-only grid-items-0 SummaryListWrapper-ejYbXR hcITxN summary-list SelectedStoriesList-gBcbFG ensbav" data-journey-hook="grid-wrapper">
#                 <div class="GridItem-beYvyV bRelOV grid--item">
#                  <div>
#                   <div class="summary-list__items">
#                    <div class="StackedRatingsCardWrapper-ghvskg ffDePc SummaryItemWrapper-ircdWR llfpff summary-list__item" data-section-title="Author Spotlight/Story 1">
#                     <div class="ImageWrapper-chXNAU ftRvdL">
#                      <span class="SpanWrapper-zEXFr koTknX responsive-asset Image-bQSkvr bVFNUa">
#                       <div class="AspectRatioContainer-bEozCe dKhhoi" data-testid="aspect-ratio-container">
#                        <div class="aspect-ratio--overlay-container">
#                         <picture class="ResponsiveImagePicture-cGZhnX jwYQWO Image-bQSkvr bVFNUa responsive-image">
#                          <source media="(max-width: 767px)" sizes="100vw" srcset="https://assets.epicurious.com/photos/5bc5fc5585e5302d76507a82/3:4/w_120,c_limit/One%20Bottle%20Cocktail_Mr.%20Tingles'%20Punch.jpg 120w, https://assets.epicurious.com/photos/5bc5fc5585e5302d76507a82/3:4/w_240,c_limit/One%20Bottle%20Cocktail_Mr.%20Tingles'%20Punch.jpg 240w, https://assets.epicurious.com/photos/5bc5fc5585e5302d76507a82/3:4/w_320,c_limit/One%20Bottle%20Cocktail_Mr.%20Tingles'%20Punch.jpg 320w, https://assets.epicurious.com/photos/5bc5fc5585e5302d76507a82/3:4/w_640,c_limit/One%20Bottle%20Cocktail_Mr.%20Tingles'%20Punch.jpg 640w"/>
#                          <source media="(min-width: 768px)" sizes="100vw" srcset="https://assets.epicurious.com/photos/5bc5fc5585e5302d76507a82/3:4/w_120,c_limit/One%20Bottle%20Cocktail_Mr.%20Tingles'%20Punch.jpg 120w, https://assets.epicurious.com/photos/5bc5fc5585e5302d76507a82/3:4/w_240,c_limit/One%20Bottle%20Cocktail_Mr.%20Tingles'%20Punch.jpg 240w, https://assets.epicurious.com/photos/5bc5fc5585e5302d76507a82/3:4/w_320,c_limit/One%20Bottle%20Cocktail_Mr.%20Tingles'%20Punch.jpg 320w, https://assets.epicurious.com/photos/5bc5fc5585e5302d76507a82/3:4/w_640,c_limit/One%20Bottle%20Cocktail_Mr.%20Tingles'%20Punch.jpg 640w, https://assets.epicurious.com/photos/5bc5fc5585e5302d76507a82/3:4/w_960,c_limit/One%20Bottle%20Cocktail_Mr.%20Tingles'%20Punch.jpg 960w"/>
#                          <img alt="31 Fall Cocktails to Sip Your Way Through Cozy Season" class="ResponsiveImageContainer-eNxvmU cfBbTk responsive-image__image" data-src="https://assets.epicurious.com/photos/5bc5fc5585e5302d76507a82/3:4/w_1024%2Cc_limit/One%2520Bottle%2520Cocktail_Mr.%2520Tingles'%2520Punch.jpg" loading="lazy" src="https://assets.epicurious.com/photos/5bc5fc5585e5302d76507a82/3:4/w_1024%2Cc_limit/One%2520Bottle%2520Cocktail_Mr.%2520Tingles'%2520Punch.jpg"/>
#                         </picture>
#                        </div>
#                       </div>
#                      </span>
#                      <div class="BaseButton-lbLhfD ButtonWrapper-igqDZ frFMjA kQBHiR button button--utility InlineVideoItemIconButton-kbRQes StackedRatingsCardImageIcon-kNtrwP dXwrHB hlVTXR" data-event-click='{"element":"Button"}' data-testid="Button" type="">
#                       <span class="ButtonLabel-cyWivE hvohFn button__label">
#                        icon
#                       </span>
#                       <div class="ButtonIconWrapper-gzKJtq bQqPLN button__icon-container">
#                        <svg class="ButtonIcon-bdIQNJ jKYSoZ button-icon icon icon-gallery" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                         <title>
#                          Gallery
#                         </title>
#                         <path clip-rule="evenodd" d="M17.5 6.5h-13v9H6V8h11.5V6.5ZM19 8V5H3v12h3v2h15V8h-2ZM7.5 9.5h12v8h-12v-8Z" fill="#000" fill-rule="evenodd">
#                         </path>
#                        </svg>
#                       </div>
#                      </div>
#                     </div>
#                     <div class="ContentWrapper-bCkkJm deWMOT">
#                      <div class="Content-ifkqHN yjlRJ">
#                       <div class="Body-hsMkus hIjmI">
#                        <div class="ClampWrapper-kUepdg jwmzUV clamp" data-testid="ClampWrapper">
#                         <div class="ClampContent-hcSZcW hKLEHH">
#                          <a class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh Link-ecECcQ deqABF ijWuNu fkcGxl" href="/recipes-menus/fall-cocktails">
#                           <h3 class="BaseWrap-sc-gzmcOU BaseText-eqOrNE Hed-gQCsFV deqABF gNRPUh fEQvtj">
#                            31 Fall Cocktails to Sip Your Way Through Cozy Season
#                           </h3>
#                          </a>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                    <div class="StackedRatingsCardWrapper-ghvskg ffDePc SummaryItemWrapper-ircdWR llfpff summary-list__item" data-section-title="Author Spotlight/Story 2">
#                     <div class="ImageWrapper-chXNAU ftRvdL">
#                      <span class="SpanWrapper-zEXFr koTknX responsive-asset Image-bQSkvr bVFNUa">
#                       <div class="AspectRatioContainer-bEozCe dKhhoi" data-testid="aspect-ratio-container">
#                        <div class="aspect-ratio--overlay-container">
#                         <picture class="ResponsiveImagePicture-cGZhnX jwYQWO Image-bQSkvr bVFNUa responsive-image">
#                          <source media="(max-width: 767px)" sizes="100vw" srcset="https://assets.epicurious.com/photos/62f16ed5fe4be95d5a460eed/3:4/w_120,c_limit/RoastChicken_RECIPE_080420_37993.jpg 120w, https://assets.epicurious.com/photos/62f16ed5fe4be95d5a460eed/3:4/w_240,c_limit/RoastChicken_RECIPE_080420_37993.jpg 240w, https://assets.epicurious.com/photos/62f16ed5fe4be95d5a460eed/3:4/w_320,c_limit/RoastChicken_RECIPE_080420_37993.jpg 320w, https://assets.epicurious.com/photos/62f16ed5fe4be95d5a460eed/3:4/w_640,c_limit/RoastChicken_RECIPE_080420_37993.jpg 640w"/>
#                          <source media="(min-width: 768px)" sizes="100vw" srcset="https://assets.epicurious.com/photos/62f16ed5fe4be95d5a460eed/3:4/w_120,c_limit/RoastChicken_RECIPE_080420_37993.jpg 120w, https://assets.epicurious.com/photos/62f16ed5fe4be95d5a460eed/3:4/w_240,c_limit/RoastChicken_RECIPE_080420_37993.jpg 240w, https://assets.epicurious.com/photos/62f16ed5fe4be95d5a460eed/3:4/w_320,c_limit/RoastChicken_RECIPE_080420_37993.jpg 320w, https://assets.epicurious.com/photos/62f16ed5fe4be95d5a460eed/3:4/w_640,c_limit/RoastChicken_RECIPE_080420_37993.jpg 640w, https://assets.epicurious.com/photos/62f16ed5fe4be95d5a460eed/3:4/w_960,c_limit/RoastChicken_RECIPE_080420_37993.jpg 960w"/>
#                          <img alt="Simple Roast Chicken" class="ResponsiveImageContainer-eNxvmU cfBbTk responsive-image__image" data-src="https://assets.epicurious.com/photos/62f16ed5fe4be95d5a460eed/3:4/w_1024%2Cc_limit/RoastChicken_RECIPE_080420_37993.jpg" loading="lazy" src="https://assets.epicurious.com/photos/62f16ed5fe4be95d5a460eed/3:4/w_1024%2Cc_limit/RoastChicken_RECIPE_080420_37993.jpg"/>
#                         </picture>
#                        </div>
#                       </div>
#                      </span>
#                     </div>
#                     <div class="ContentWrapper-bCkkJm deWMOT">
#                      <div class="Content-ifkqHN yjlRJ">
#                       <div class="Body-hsMkus hIjmI">
#                        <div class="ClampWrapper-kUepdg jwmzUV clamp" data-testid="ClampWrapper">
#                         <div class="ClampContent-hcSZcW hKLEHH">
#                          <a class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh Link-ecECcQ deqABF ijWuNu fkcGxl" href="/recipes/food/views/my-favorite-simple-roast-chicken-231348">
#                           <h3 class="BaseWrap-sc-gzmcOU BaseText-eqOrNE Hed-gQCsFV deqABF gNRPUh fEQvtj">
#                            Simple Roast Chicken
#                           </h3>
#                          </a>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                      <div class="MetaData-bjevUx fRIzEv">
#                       <div class="StyledRatings-cdFVqf dyjvSq">
#                        <div class="RatingWrapper-bWyTJA hmNReC StackedRatingsCardStars-djQXUY jYWEcb" data-testid="RatingWrapper">
#                         <div class="RatingFormWrapper-bmbFgi fBJMkW">
#                          <p class="BaseWrap-sc-gzmcOU BaseText-eqOrNE RatingRating-bJravU deqABF fmWmyQ fgPsvs">
#                           5.0
#                          </p>
#                          <form action="" class="RatingForm-jcxMJh kjewKr" data-testid="rating-form">
#                           <div aria-label="Rating" class="RatingStars-iURqAQ iobXOd" role="group">
#                            <input aria-label="0 Rating" class="RatingInput-ccHABN fzuyjx" disabled="" id="Rating0-wjjdyh" name="Rating" type="radio" value="0"/>
#                            <label class="RatingLabel-cTXwMB IfkO" for="Rating0-wjjdyh">
#                            </label>
#                            <input aria-label="1 Rating" class="RatingInput-ccHABN fzuyjx" disabled="" id="Rating1-p1tm5" name="Rating" type="radio" value="1"/>
#                            <label class="RatingLabel-cTXwMB IfkO" for="Rating1-p1tm5">
#                             <div class="RatingStar-bDVkyb jofiAG">
#                              <svg class="icon icon-rating-half RatingStarHalf-kKVCTE fPHLgP" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#                               <path d="M4.789 9.391a.551.551 0 0 1 .184.604L3.564 14.58a.324.324 0 0 0 .193.403.29.29 0 0 0 .28-.044l3.657-2.809A.517.517 0 0 1 8 12.025V1a.315.315 0 0 0-.271.219L6.32 5.646a.516.516 0 0 1-.481.368H1.307A.306.306 0 0 0 1 6.329a.297.297 0 0 0 .123.254L4.789 9.39Z" fill="#000">

# %% [markdown]
# ###### [Back to top](#Index:)
#
# ### Question 3: Extract the Page Title
#
# Let’s extract the **title of the web page** using BeautifulSoup.
#
# #### Instructions
#
# 1. Use the `.find()` method of the `BeautifulSoup` object `soup` to locate the `<title>` tag.
# 2. Assign the resulting tag (including its content) to a variable named `ans3`.
# 3. Print `ans3` to verify that it correctly captures the page title.
#
# > The `<title>` tag usually contains the text shown in the browser tab and is located within the `<head>` section of the HTML.
#
# ---
#
# **Expected Output Example**
# ```html
# <title>Epicurious – Recipes, Menu Ideas, Videos &amp; Cooking Tips | Epicurious</title>
# ```
#
# **Note:** `&amp;` or `&` are both fine.

# %%
ans3 = None
ans3 = soup.find('title')

# Answer test
print(ans3)
# Out:
# <title>Epicurious – Recipes, Menu Ideas, Videos &amp; Cooking Tips | Epicurious</title>

# %% [markdown]
# ###### [Back to top](#Index:)
#
# ### Question 4: Extract All Hyperlinks
#
# In this task, you will extract all the hyperlinks (`<a>` tags) from the page.
#
# #### Instructions
#
# 1. Use the `.find_all()` method of your `BeautifulSoup` object (`soup`) to find **all** `<a>` tags on the page.
# 2. Assign the result (a list of all anchor tags) to a variable named `ans4`.
# 3. Print `ans4` to visually inspect the list of hyperlinks and compare them with what you see in the website’s HTML.
#
# > Each `<a>` tag typically contains an `href` attribute which holds the actual link.
#
# ---
#
# **Expected Output Example**
# A portion of the printed list might look like this:
# ```html
# [<a aria-controls="main-navigation" class="show-main-navigation"...]
# ```
#
# **Hint**: Use **`soup.find_all`**.

# %%
ans4 = None
ans4 = soup.find_all('a')

# Answer test
print(ans4)
# Out:
# [<a class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh BasePageSkipLink-PCnJP deqABF dVfXDd cLqibi kedKxB" data-testid="BasePageSkipLink" href="#main-content">Skip to main content</a>, <a class="StackedNavigationLogoLink-bOjeJG jWIPUQ" data-testid="Logo" href="/"><picture class="ResponsiveImagePicture-cGZhnX jwYQWO responsive-image"><img alt="Epicurious" class="ResponsiveImageContainer-eNxvmU cfBbTk responsive-image__image" sizes="100vw" src="/verso/static/epicurious-us/assets/logo.svg" srcset=""/></picture></a>, <a class="NavigationInternalLink-dbWQlJ cNvrNX navigation__link" data-testid="navigation__internal-link" href="/newsletter" role="link">Newsletter</a>, <a aria-expanded="false" class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh NavLink-uSZst deqABF dVfXDd hsENAC gOglim" data-testid="ScrollingNavigationLink" href="/recipes-menus" role="link" tabindex="0"><span>Recipes</span></a>, <a aria-expanded="false" class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh NavLink-uSZst deqABF dVfXDd hsENAC gOglim" data-testid="ScrollingNavigationLink" href="/ingredients" role="link" tabindex="0"><span>Ingredients</span></a>, <a aria-expanded="false" class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh NavLink-uSZst deqABF dVfXDd hsENAC gOglim" data-testid="ScrollingNavigationLink" href="/holidays-events" role="link" tabindex="0"><span>Occasions</span></a>, <a aria-expanded="false" class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh NavLink-uSZst deqABF dVfXDd hsENAC gOglim" data-testid="ScrollingNavigationLink" href="/shopping" role="link" tabindex="0"><span>Kitchen Gear</span></a>, <a class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh NavLink-uSZst deqABF dVfXDd hsENAC kkiAoT" data-testid="ScrollingNavigationLink" href="/expert-advice" role="link" tabindex="0"><span>Techniques</span></a>, <a class="StackedNavigationLogoLink-bOjeJG jWIPUQ" href="/"><picture class="ResponsiveImagePicture-cGZhnX jwYQWO responsive-image"><img alt="Epicurious" class="ResponsiveImageContainer-eNxvmU cfBbTk responsive-image__image" sizes="100vw" src="/verso/static/epicurious-us/assets/logo-header.svg" srcset=""/></picture></a>, <a class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh Link-ecECcQ deqABF ijWuNu fkcGxl" href="/recipes/food/views/spatchcocked-turkey"><h3 class="BaseWrap-sc-gzmcOU BaseText-eqOrNE Hed-gQCsFV deqABF gNRPUh fEQvtj">Spatchcocked Turkey With Garlic-Thyme Butter</h3></a>, <a class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh Link-ecECcQ deqABF ijWuNu fkcGxl" href="/holidays-events/how-to-thaw-turkey-fast-article"><h3 class="BaseWrap-sc-gzmcOU BaseText-eqOrNE Hed-gQCsFV deqABF gNRPUh fEQvtj">How to Thaw a Turkey Depending on How Much Time You Have</h3></a>, <a class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh Link-ecECcQ deqABF ijWuNu fkcGxl" href="/recipes-menus/most-saved-recipes-november-2025"><h3 class="BaseWrap-sc-gzmcOU BaseText-eqOrNE Hed-gQCsFV deqABF gNRPUh fEQvtj">The Most-Saved Recipes in the Epicurious App This Week</h3></a>, <a class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh Link-ecECcQ deqABF ijWuNu fkcGxl" href="/recipes/food/views/crispy-baked-wings-with-berbere-honey-glaze-and-fried-garlic"><h3 class="BaseWrap-sc-gzmcOU BaseText-eqOrNE Hed-gQCsFV deqABF gNRPUh fEQvtj">Crispy Baked Wings With Berbere Honey Glaze and Fried Garlic</h3></a>, <a class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh Link-ecECcQ deqABF ijWuNu fkcGxl" href="/recipes/food/views/fufu"><h3 class="BaseWrap-sc-gzmcOU BaseText-eqOrNE Hed-gQCsFV deqABF gNRPUh fEQvtj">Fufu</h3></a>, <a class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh Link-ecECcQ deqABF ijWuNu fkcGxl" href="/recipes/food/views/baked-butter-paneer"><h3 class="BaseWrap-sc-gzmcOU BaseText-eqOrNE Hed-gQCsFV deqABF gNRPUh fEQvtj">Baked Butter Paneer</h3></a>, <a class="BaseWrap-sc-gzmcOU BaseText-eqOrNE BaseLink-eTpkqh Link-ecECcQ deqABF ijWuNu fkcGxl" href="/recipes/food/views/oyster-mushroom-skewers-with-bok-ch ...

# %% [markdown]
# ###### [Back to top](#Index:)
#
# ### Question 5: Locate Recipe Cards by Tag and Class
#
# Now that you’ve explored the page’s structure, you’ll focus on finding specific HTML elements that represent **recipe cards**. These are often located within `<article>` tags and associated with specific class names such as `"recipe-of-the-day"` (or similar — inspect to confirm).
#
# #### Instructions
#
# 1. Inspect the web page and search the HTML for tags related to **recipes**. Look for `article` tags with meaningful `class` attributes (e.g., `class="recipe-content-card"` or similar).
# 2. Use `soup.find_all()` to locate all such `article` tags with the relevant class.
# 3. Assign the result (a list of matching article elements) to a variable named `ans5`.
# 4. Print `ans5` to view the raw HTML snippets retrieved.
#
# ```python
# soup.find_all('...', class_='...')
# ```
#
# **Note:** Use `class_` (with underscore) instead of `class`, as `class` is a reserved keyword in Python.
#
# **Expected Output** A list of `<article>` elements containing recipe data. It may be empty if there are no recipe of the day.

# %%
ans5 = None
ans5 = soup.find_all('article',class_="recipe-of-the-day")

# Answer test
print(ans5)
# Out:
# []
